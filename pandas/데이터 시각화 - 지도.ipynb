# %%
#!pip install folium # 지도 위에 시각화할 때 유용한 도구 (세계 지도를 기본 지원하고 다양한 스타일의 지도 이미지를 제공)

# %%
import folium

# %% [markdown]
# ## 기본 맵

# %%
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12)
seoul_map.save('./seoul.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba9b4bff29a5ac0766dbb3a7f2377d2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba9b4bff29a5ac0766dbb3a7f2377d2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ba9b4bff29a5ac0766dbb3a7f2377d2c = L.map(
#                 &quot;map_ba9b4bff29a5ac0766dbb3a7f2377d2c&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_129e371bbd0bf75d92df60690819ca03 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba9b4bff29a5ac0766dbb3a7f2377d2c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  Stamen Terrain 맵

# %%
seoul_map2 = folium.Map(location=[37.55, 126.98],tiles='Stamen Terrain' ,zoom_start=12) # 산악 지형 등의 지형이 보다 선명하게 드러남
seoul_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0661c8869a015271685392ebf60578e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0661c8869a015271685392ebf60578e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0661c8869a015271685392ebf60578e3 = L.map(
#                 &quot;map_0661c8869a015271685392ebf60578e3&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cca2cc3fca5662c6a1ea1c03f5952f80 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0661c8869a015271685392ebf60578e3);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Stamen Toner 맵

# %%
seoul_map3 = folium.Map(location=[37.55, 126.98],tiles='Stamen Toner' ,zoom_start=12) # 은 흑백 스타일로 도로망을 강조
seoul_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da22ef5dec8356044a28c1a05682a137 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da22ef5dec8356044a28c1a05682a137&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_da22ef5dec8356044a28c1a05682a137 = L.map(
#                 &quot;map_da22ef5dec8356044a28c1a05682a137&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d631540c45a055925adf4c48977c7c53 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da22ef5dec8356044a28c1a05682a137);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 서울지역 대학교 위치

# %% [markdown]
# ## 지도에 Marker 표시

# %%
import pandas as pd

# %%
df = pd.read_excel('./sample/서울지역 대학교 위치.xlsx',engine='openpyxl')
df.head()
# Out:
#      Unnamed: 0         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
seoul_map = folium.Map(location = [37.55, 126.98], tiles='Stamen Terrain', zoom_start = 12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_293907d03f8642d7160363f5e27d1248 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_293907d03f8642d7160363f5e27d1248&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_293907d03f8642d7160363f5e27d1248 = L.map(
#                 &quot;map_293907d03f8642d7160363f5e27d1248&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68f7dd646346d50123c87210e2884255 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat, lng], popup = name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_293907d03f8642d7160363f5e27d1248 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_293907d03f8642d7160363f5e27d1248&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_293907d03f8642d7160363f5e27d1248 = L.map(
#                 &quot;map_293907d03f8642d7160363f5e27d1248&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68f7dd646346d50123c87210e2884255 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#             var marker_e7484180ed86933d68e20335d93b435a = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#         var popup_1fe03d4c8b7f24e1ad9d509dd7a8ab53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5cea36e9e0e0f13d708b5700e6fdbefe = $(`&lt;div id=&quot;html_5cea36e9e0e0f13d708b5700e6fdbefe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_1fe03d4c8b7f24e1ad9d509dd7a8ab53.setContent(html_5cea36e9e0e0f13d708b5700e6fdbefe);
#
#
#         marker_e7484180ed86933d68e20335d93b435a.bindPopup(popup_1fe03d4c8b7f24e1ad9d509dd7a8ab53)
#         ;
#
#
#
#
#             var marker_08e0cd67b0be3e2d73a7870a799fca2b = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#         var popup_595c9ff4ea5a9ca86334c5efe983517d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2fbb8f4e93f2b8cdeb3ccb8d2e124375 = $(`&lt;div id=&quot;html_2fbb8f4e93f2b8cdeb3ccb8d2e124375&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_595c9ff4ea5a9ca86334c5efe983517d.setContent(html_2fbb8f4e93f2b8cdeb3ccb8d2e124375);
#
#
#         marker_08e0cd67b0be3e2d73a7870a799fca2b.bindPopup(popup_595c9ff4ea5a9ca86334c5efe983517d)
#         ;
#
#
#
#
#             var marker_f9d987ac6f157937b2541ca5b99f58cc = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#         var popup_88a36c935eee4f9c0239fa77c80251d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d3249ba4b7bd13982807fd7414097ab8 = $(`&lt;div id=&quot;html_d3249ba4b7bd13982807fd7414097ab8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_88a36c935eee4f9c0239fa77c80251d6.setContent(html_d3249ba4b7bd13982807fd7414097ab8);
#
#
#         marker_f9d987ac6f157937b2541ca5b99f58cc.bindPopup(popup_88a36c935eee4f9c0239fa77c80251d6)
#         ;
#
#
#
#
#             var marker_5d8c10d62c9bc291f86f15300253e730 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#         var popup_e00edf6913d2fa38a7810110beff1dfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e1315652b5b7b2a7c7dc6c957e1003e0 = $(`&lt;div id=&quot;html_e1315652b5b7b2a7c7dc6c957e1003e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#             popup_e00edf6913d2fa38a7810110beff1dfe.setContent(html_e1315652b5b7b2a7c7dc6c957e1003e0);
#
#
#         marker_5d8c10d62c9bc291f86f15300253e730.bindPopup(popup_e00edf6913d2fa38a7810110beff1dfe)
#         ;
#
#
#
#
#             var marker_87f02d52119960012710afbb4755ff06 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#         var popup_18fb96772933eba4d6c6e31a4cf5123d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_84c38d21dd8584edcc2145b314d48adb = $(`&lt;div id=&quot;html_84c38d21dd8584edcc2145b314d48adb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#             popup_18fb96772933eba4d6c6e31a4cf5123d.setContent(html_84c38d21dd8584edcc2145b314d48adb);
#
#
#         marker_87f02d52119960012710afbb4755ff06.bindPopup(popup_18fb96772933eba4d6c6e31a4cf5123d)
#         ;
#
#
#
#
#             var marker_a773cebf627fe89e67e28a9e10ffae75 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_293907d03f8642d7160363f5e27d1248);
#
#
#         var popup_f5914da4817a641272049db56d1ff9a4 = L.popup(

# %% [markdown]
# ## 속성 변환

# %%
seoul_map = folium.Map(location = [37.55, 126.98], tiles='Stamen Terrain', zoom_start = 12)

for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                  radius = 10,
                  color = 'brown',
                  fill = True,
                  fill_color = 'coral',
                  fill_opacity = 0.7,
                  popup = name,
                 ).add_to(seoul_map)
    
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80d3bffe01f390c9aa53bf07aa3eb779 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80d3bffe01f390c9aa53bf07aa3eb779&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_80d3bffe01f390c9aa53bf07aa3eb779 = L.map(
#                 &quot;map_80d3bffe01f390c9aa53bf07aa3eb779&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b29dedfee47b4c615112e331f8a63d3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80d3bffe01f390c9aa53bf07aa3eb779);
#
#
#             var circle_marker_ac75c7454881e0d619f35a3230682ea3 = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_80d3bffe01f390c9aa53bf07aa3eb779);
#
#
#         var popup_89e1a97f8fbf48b1aec7e7875f14839b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2ec6f34f4d0ff864d1623fb581f92a28 = $(`&lt;div id=&quot;html_2ec6f34f4d0ff864d1623fb581f92a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_89e1a97f8fbf48b1aec7e7875f14839b.setContent(html_2ec6f34f4d0ff864d1623fb581f92a28);
#
#
#         circle_marker_ac75c7454881e0d619f35a3230682ea3.bindPopup(popup_89e1a97f8fbf48b1aec7e7875f14839b)
#         ;
#
#
#
#
#             var circle_marker_c2309fa06b297ef7bcbdf81f07fcd36f = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_80d3bffe01f390c9aa53bf07aa3eb779);
#
#
#         var popup_2449e13e4d4dc2fb98a5ce7c94e7a0d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3a8985f77e8c2042b6e3614923d39bab = $(`&lt;div id=&quot;html_3a8985f77e8c2042b6e3614923d39bab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_2449e13e4d4dc2fb98a5ce7c94e7a0d9.setContent(html_3a8985f77e8c2042b6e3614923d39bab);
#
#
#         circle_marker_c2309fa06b297ef7bcbdf81f07fcd36f.bindPopup(popup_2449e13e4d4dc2fb98a5ce7c94e7a0d9)
#         ;
#
#
#
#
#             var circle_marker_a26b2e31d62060d4049370d7e54e3208 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_80d3bffe01f390c9aa53bf07aa3eb779);
#
#
#         var popup_f3fb70b153dcad748758b4d516691a27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5970e72bdddcdc3feff16d7a7145f7ae = $(`&lt;div id=&quot;html_5970e72bdddcdc3feff16d7a7145f7ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_f3fb70b153dcad748758b4d516691a27.setContent(html_5970e72bdddcdc3feff16d7a7145f7ae);
#
#
#         circle_marker_a26b2e31d62060d4049370d7e54e3208.bindPopup(popup_f3fb70b153dcad748758b4d516691a27)
#         ;
#
#
#
#
#             var circle_marker_11df9dbe283926cd7da54dba6b5432af = L.circleMarker(
#                 [37.4996227, 127.0060653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;

# %% [markdown]
# # 지도 영역에 단계구분도(Choropleth Map) 표시

# %%
import json

# %%
df = pd.read_excel('./sample/경기도인구데이터.xlsx', index_col='구분', engine='openpyxl')
df.columns = df.columns.map(str)
df.head()
# Out:
#           2007    2008    2009    2010    2011    2012    2013    2014  \
# 구분
# 수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
#
#           2015    2016    2017
# 구분
# 수원시장안구  299016  296479  293828
# 수원시권선구  351053  358393  365653
# 수원시팔달구  199180  198515  193311
# 수원시영통구  335375  340654  349836
# 성남시수정구  219531  232841  236932

# %%
geo_path = './sample/경기도행정구역경계.json'
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))

g_map = folium.Map(location=[37.5502,126.982], titles = 'Stamen Terrain', zoom_start=9)
year = '2017'

# %%
# # Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,
                  data = df['2007'],
                  columns=[df.index, df[year]],
                  fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                  threshold_scale=[10000, 100000, 300000, 500000, 700000], 
                  key_on = 'feature.properties.name'
                 ).add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a77bd0fb437c1effadd44089bb58ee35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a77bd0fb437c1effadd44089bb58ee35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a77bd0fb437c1effadd44089bb58ee35 = L.map(
#                 &quot;map_a77bd0fb437c1effadd44089bb58ee35&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d84857fe06d38d2a8ca7bdab1239597 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a77bd0fb437c1effadd44089bb58ee35);
#
#
#             var choropleth_6bb526eacb4cedbb51d8807ccee4c9ff = L.featureGroup(
#                 {}
#             ).addTo(map_a77bd0fb437c1effadd44089bb58ee35);
#
#
#         function geo_json_e7d050e7f1dd1f7bcef77195b53bee75_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31380: case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31200: case 31192: case 31150: case 31130: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31023: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e7d050e7f1dd1f7bcef77195b53bee75_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e7d050e7f1dd1f7bcef77195b53bee75 = L.geoJson(null, {
#                 onEachFeature: geo_json_e7d050e7f1dd1f7bcef77195b53bee75_onEachFeature,
#
#                 style: geo_json_e7d050e7f1dd1f7bcef77195b53bee75_styler,
#         });
#
#         function geo_json_e7d050e7f1dd1f7bcef77195b53bee75_add (data) {
#             geo_json_e7d050e7f1dd1f7bcef77195b53bee75
#                 .addData(data)
#                 .addTo(choropleth_6bb526eacb4cedbb51d8807ccee4c9ff);
#         }
#             geo_json_e7d050e7f1dd1f7bcef77195b53bee75_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.39174400683049, 37.4256483411369], [127.40276739880215, 37.41856433413549], [127.4250053080982, 37.43669952587185], [127.4817900304572, 37.42084413829662], [127.51015267026155, 37.43699555518635], [127.52501209957308, 37.43192043868044], [127.53910572062166, 37.40849283821634], [127.60528700481163, 37.416969769508924], [127.63754040237271, 37.41065607591271], [127.6491838950862, 37.402042953108506], [127.66976823475012, 37.40884431255766], [127.71071536074867, 37.40736583858037], [127.70347417929173, 37.371054026073324], [127.76165381178268, 37.36421926003675], [127.77952402154285, 37.368441789396854], [127.80397287036232, 37.432516049235865], [127.79833492163134, 37.460500237870505], [127.77664798308412, 37.48883635932707], [127.77611527652192, 37.50328615763377], [127.80855972024105, 37.53220450961153], [127.8445769305193, 37.53621789699497], [127.85162286006927, 37.55037340096326], [127.81507964099751, 37.5618389022189], [127.79492564827493, 37.58252978378627], [127.76838776707211, 37.580178216134605], [127.75614914198108, 37.589477424718204], [127.7102810556826, 37.58360128682645], [127.69869383868397, 37.59757031454811], [127.65553070991882, 37.61954565135447], [127.62972032693943, 37.63983122973888], [127.60450569091653, 37.648548552427314], [127.5816670144209

# %%
# # Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,
                  data = df[year],
                  columns=[df.index, df[year]],
                  fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                  threshold_scale=[10000, 100000, 300000, 500000, 700000], 
                  key_on = 'feature.properties.name'
                 ).add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a77bd0fb437c1effadd44089bb58ee35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a77bd0fb437c1effadd44089bb58ee35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a77bd0fb437c1effadd44089bb58ee35 = L.map(
#                 &quot;map_a77bd0fb437c1effadd44089bb58ee35&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d84857fe06d38d2a8ca7bdab1239597 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a77bd0fb437c1effadd44089bb58ee35);
#
#
#             var choropleth_6bb526eacb4cedbb51d8807ccee4c9ff = L.featureGroup(
#                 {}
#             ).addTo(map_a77bd0fb437c1effadd44089bb58ee35);
#
#
#         function geo_json_e7d050e7f1dd1f7bcef77195b53bee75_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31380: case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31200: case 31192: case 31150: case 31130: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31023: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e7d050e7f1dd1f7bcef77195b53bee75_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e7d050e7f1dd1f7bcef77195b53bee75 = L.geoJson(null, {
#                 onEachFeature: geo_json_e7d050e7f1dd1f7bcef77195b53bee75_onEachFeature,
#
#                 style: geo_json_e7d050e7f1dd1f7bcef77195b53bee75_styler,
#         });
#
#         function geo_json_e7d050e7f1dd1f7bcef77195b53bee75_add (data) {
#             geo_json_e7d050e7f1dd1f7bcef77195b53bee75
#                 .addData(data)
#                 .addTo(choropleth_6bb526eacb4cedbb51d8807ccee4c9ff);
#         }
#             geo_json_e7d050e7f1dd1f7bcef77195b53bee75_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.39174400683049, 37.4256483411369], [127.40276739880215, 37.41856433413549], [127.4250053080982, 37.43669952587185], [127.4817900304572, 37.42084413829662], [127.51015267026155, 37.43699555518635], [127.52501209957308, 37.43192043868044], [127.53910572062166, 37.40849283821634], [127.60528700481163, 37.416969769508924], [127.63754040237271, 37.41065607591271], [127.6491838950862, 37.402042953108506], [127.66976823475012, 37.40884431255766], [127.71071536074867, 37.40736583858037], [127.70347417929173, 37.371054026073324], [127.76165381178268, 37.36421926003675], [127.77952402154285, 37.368441789396854], [127.80397287036232, 37.432516049235865], [127.79833492163134, 37.460500237870505], [127.77664798308412, 37.48883635932707], [127.77611527652192, 37.50328615763377], [127.80855972024105, 37.53220450961153], [127.8445769305193, 37.53621789699497], [127.85162286006927, 37.55037340096326], [127.81507964099751, 37.5618389022189], [127.79492564827493, 37.58252978378627], [127.76838776707211, 37.580178216134605], [127.75614914198108, 37.589477424718204], [127.7102810556826, 37.58360128682645], [127.69869383868397, 37.59757031454811], [127.65553070991882, 37.61954565135447], [127.62972032693943, 37.63983122973888], [127.60450569091653, 37.648548552427314], [127.5816670144209

# %% [markdown]
# 2007년과 비교하면 남양주, 분당, 화성(동탄) 지역의 신도시 개발과 인구 유입으로인구가 집중되는 현상이 심화된 것을 볼 수 있다.

# %% [markdown]
# # 공공 데이터 활용

# %%
df = pd.read_csv('./sample/서울시 응급실 위치 정보.csv', encoding='cp949')
df
# Out:
#         기관ID                                     주소 병원분류 병원분류명 응급의료기관코드  \
# 0   A1100008        서울특별시 성북구 고려대로 73 고려대병원 (안암동5가)    A  종합병원     G001
# 1   A1100011       서울특별시 영등포구 63로 10 여의도성모병원 (여의도동)    A  종합병원     G006
# 2   A1121013               서울특별시 은평구 통일로 1021 (진관동)    A  종합병원     G006
# 3   A1100047                서울특별시 관악구 관악로 242 (봉천동)    B    병원     G009
# 4   A1100076       서울특별시 관악구 남부순환로 1449 (신림동 서울본병원)    B    병원     G009
# ..       ...                                    ...  ...   ...      ...
# 63  A1100038  서울특별시 영등포구 버드나루로7길 12 (영등포동7가 한강성심병원)    A  종합병원     G009
# 64  A1100013             서울특별시 성동구 왕십리로 222-1 (사근동)    A  종합병원     G001
# 65  A1100051                 서울특별시 광진구 자양로 85 (자양동)    A  종합병원     G007
# 66  A1100019         서울특별시 양천구 목동로 225 홍익병원본관 (신정동)    A  종합병원     G007
# 67  A1100049               서울특별시 금천구 시흥대로 244 (시흥동)    A  종합병원     G007
#
#     응급의료기관코드명  응급실운영여부                                                 비고  \
# 0    권역응급의료센터        1                                         토요일 25째 휴무
# 1    지역응급의료센터        1                                      일요일은 교정진료만 운영
# 2    지역응급의료센터        1                                      일요일은 교정진료만 운영
# 3   응급실운영신고기관        1  접수는 평일 16시 토요일은 12시전까지만 가능합니다.  공휴일은 요일에 맞춰 진료...
# 4   응급실운영신고기관        1                                   점심시간 12:30~13:30
# ..        ...      ...                                                ...
# 63  응급실운영신고기관        1                             진료과에따라 상이함(연락 후 내원 바람)
# 64   권역응급의료센터        1                                      점심시간: 13시~14시
# 65   지역응급의료기관        1                                   점심시간 13:00~14:00
# 66   지역응급의료기관        1                          평일 30분전 접수마감 토요일 13시 접수마감
# 67   지역응급의료기관        1                                   점심시간 12:00-13:00
#
#                                  기관설명상세  \
# 0                       건강검진센터 내과진료만 가능
# 1                소아과 평일) 9-18시 토) 9-14시
# 2                소아과 평일) 9-18시 토) 9-14시
# 3           점심시간 : 오후 1시-오후 2시 전화 예약 가능
# 4         관악구 봉천동 187병상 투석 가능한 요양병원입니다.
# ..                                  ...
# 63                       점심 12:30~13:30
# 64                         관절염/류마티스 전문/
# 65  24시간 전문의 진료가 가능한 서울 동북부 지역 거점병원입니다.
# 66                         후두내시경O/수액처치O
# 67                            24째 토요일휴진
#
#                                       간이약도  ... 진료시간(목요일)S 진료시간(금요일)S  \
# 0            지하철 6호선 안암역 하차 후 1번출구 도보 500m  ...        900        900
# 1                                샛강역 3번 출구  ...        900        900
# 2                                샛강역 3번 출구  ...        830        830
# 3                       서울대입구역 7번 출구 도보 5분  ...        900        900
# 4                        2호선 신대방역/난곡사거리 인근  ...        900        900
# ..                                     ...  ...        ...        ...
# 63  서울특별시 영등포구 버드나루로7길 12 (영등포동 7가 94-200)  ...        900        900
# 64                              한양대역 1번 출구  ...        900        900
# 65                 2호선 구의역 4번출구 직진방향 5분 거리  ...        830        830
# 66                               목동역 2번 출구  ...        900        900
# 67                             금천구청역 1번 출구  ...        830        830
#
#    진료시간(토요일)S  진료시간(일요일)S  진료시간(공휴일)S  우편번호1  우편번호2        병원경도       병원위도  \
# 0         900         900         900     28     41  127.026471  37.587156
# 1         900        1000           0     73     45  126.936731  37.518272
# 2         830        1000           0     33     12  126.916150  37.633608
# 3         900        1000         900     87     35  126.956781  37.485618
# 4         900        1000         900     87     67  126.911708  37.481585
# ..        ...         ...         ...    ...    ...         ...        ...
# 63        830        1000        1000     72     47  126.910330  37.523467
# 64        900         930         900     47     63  127.044883  37.559945
# 65        830         900         900     50     56  127.083601  37.535316
# 66        900        1000        1000     79     37  126.863664  37.528441
# 67        830        1000        1000     86     26  126.900563  37.455671
#
#                      작업시간
# 0   2022-07-07 14:55:07.0
# 1   2022-07-07 14:55:08.0
# 2   2022-07-07 14:55:08.0
# 3   2022-07-07 14:55:08.0
# 4   2022-07-07 14:55:08.0
# ..                    ...
# 63  2022-07-07 14:55:35.0
# 64  2022-07-07 14:55:35.0
# 65  2022-07-07 14:55:36.0
# 66  2022-07-07 14:55:36.0
# 67  2022-07-07 14:55:37.0
#
# [68 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['기관ID', '주소', '병원분류', '병원분류명', '응급의료기관코드', '응급의료기관코드명', '응급실운영여부', '비고',
#        '기관설명상세', '간이약도', '기관명', '대표전화1', '응급실전화', '진료시간(월요일)C', '진료시간(화요일)C',
#        '진료시간(수요일)C', '진료시간(목요일)C', '진료시간(금요일)C', '진료시간(토요일)C', '진료시간(일요일)C',
#        '진료시간(공휴일)C', '진료시간(월요일)S', '진료시간(화요일)S', '진료시간(수요일)S', '진료시간(목요일)S',
#        '진료시간(금요일)S', '진료시간(토요일)S', '진료시간(일요일)S', '진료시간(공휴일)S', '우편번호1',
#        '우편번호2', '병원경도', '병원위도', '작업시간'],
#       dtype='object')

# %%
seoul_map = folium.Map(location= [37.55, 126.98], zoom_start=12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_658a7ec8b13c119e00011787cbb8d604 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_658a7ec8b13c119e00011787cbb8d604&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_658a7ec8b13c119e00011787cbb8d604 = L.map(
#                 &quot;map_658a7ec8b13c119e00011787cbb8d604&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30220b6a8f748cf945f8b1768312e276 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for name, lat, lng in zip(df.index, df.병원위도, df.병원경도):
    folium.Marker([lat, lng], popup = name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_658a7ec8b13c119e00011787cbb8d604 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_658a7ec8b13c119e00011787cbb8d604&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_658a7ec8b13c119e00011787cbb8d604 = L.map(
#                 &quot;map_658a7ec8b13c119e00011787cbb8d604&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30220b6a8f748cf945f8b1768312e276 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#             var marker_36a470ce7a76baa7cbac973cc3a3e964 = L.marker(
#                 [37.58715608002366, 127.02647086385966],
#                 {}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#         var popup_4b0ba9e0b6f3711e4be16abdc5d7fed2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_57717d4746c815f9acadda0cb9c3720e = $(`&lt;div id=&quot;html_57717d4746c815f9acadda0cb9c3720e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_4b0ba9e0b6f3711e4be16abdc5d7fed2.setContent(html_57717d4746c815f9acadda0cb9c3720e);
#
#
#         marker_36a470ce7a76baa7cbac973cc3a3e964.bindPopup(popup_4b0ba9e0b6f3711e4be16abdc5d7fed2)
#         ;
#
#
#
#
#             var marker_66b8b8efa375721614f5c81d71adeac2 = L.marker(
#                 [37.51827233800711, 126.93673129599132],
#                 {}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#         var popup_21009e5aac5c29d7d7d36fde57cbf450 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ce50de562083fcc282964521a619f4d = $(`&lt;div id=&quot;html_3ce50de562083fcc282964521a619f4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_21009e5aac5c29d7d7d36fde57cbf450.setContent(html_3ce50de562083fcc282964521a619f4d);
#
#
#         marker_66b8b8efa375721614f5c81d71adeac2.bindPopup(popup_21009e5aac5c29d7d7d36fde57cbf450)
#         ;
#
#
#
#
#             var marker_732a5ea1610766f56ecff8793f062f44 = L.marker(
#                 [37.63360840972685, 126.91615048739686],
#                 {}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#         var popup_907ed56f34c14e24d119cd655f76d86f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9a3dd0bfaa86b1b7c2679a9d043da5a8 = $(`&lt;div id=&quot;html_9a3dd0bfaa86b1b7c2679a9d043da5a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_907ed56f34c14e24d119cd655f76d86f.setContent(html_9a3dd0bfaa86b1b7c2679a9d043da5a8);
#
#
#         marker_732a5ea1610766f56ecff8793f062f44.bindPopup(popup_907ed56f34c14e24d119cd655f76d86f)
#         ;
#
#
#
#
#             var marker_ca0f9c013675fbde4f43173287fd14d3 = L.marker(
#                 [37.485618115306, 126.95678091199277],
#                 {}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#         var popup_8a0181d29ebbac001281dfebbbe97d36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_59972b85a7449d4957aa85b6d329cef9 = $(`&lt;div id=&quot;html_59972b85a7449d4957aa85b6d329cef9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#             popup_8a0181d29ebbac001281dfebbbe97d36.setContent(html_59972b85a7449d4957aa85b6d329cef9);
#
#
#         marker_ca0f9c013675fbde4f43173287fd14d3.bindPopup(popup_8a0181d29ebbac001281dfebbbe97d36)
#         ;
#
#
#
#
#             var marker_4dc52ae012be8100da8153b29eaabb2c = L.marker(
#                 [37.4815853446168, 126.9117077397649],
#                 {}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#         var popup_eeda05f56ddb758ba34ae007071f6d81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_10870a10d018c015924f3505864a0462 = $(`&lt;div id=&quot;html_10870a10d018c015924f3505864a0462&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#             popup_eeda05f56ddb758ba34ae007071f6d81.setContent(html_10870a10d018c015924f3505864a0462);
#
#
#         marker_4dc52ae012be8100da8153b29eaabb2c.bindPopup(popup_eeda05f56ddb758ba34ae007071f6d81)
#         ;
#
#
#
#
#             var marker_b116c521e724d364d59e200f2a2e5fa2 = L.marker(
#                 [37.55347640402066, 127.15752179822285],
#                 {}
#             ).addTo(map_658a7ec8b13c119e00011787cbb8d604);
#
#
#         var popup_d6d1264130b5462daa74c29bcedee047 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_094b856275b0ea74761ce9e57123e189 = $(`&lt;div id=&quot;html_094b85
