# %%
#!pip install folium # 지도 위에 시각화할 때 유용한 도구 (세계 지도를 기본 지원하고 다양한 스타일의 지도 이미지를 제공)

# %%
import folium

# %% [markdown]
# ## 기본 맵

# %%
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12)
seoul_map.save('./seoul.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f2fb74555983b9e1581031b7961b043 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f2fb74555983b9e1581031b7961b043&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6f2fb74555983b9e1581031b7961b043 = L.map(
#                 &quot;map_6f2fb74555983b9e1581031b7961b043&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db2afd3669c8d3bc03b9381f83625745 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f2fb74555983b9e1581031b7961b043);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  Stamen Terrain 맵

# %%
seoul_map2 = folium.Map(location=[37.55, 126.98],tiles='Stamen Terrain' ,zoom_start=12) # 산악 지형 등의 지형이 보다 선명하게 드러남
seoul_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0db1d0c498a7d68288322e24a0d5545f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0db1d0c498a7d68288322e24a0d5545f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0db1d0c498a7d68288322e24a0d5545f = L.map(
#                 &quot;map_0db1d0c498a7d68288322e24a0d5545f&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11fa9759b5d24781c649ab602bef8d7f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0db1d0c498a7d68288322e24a0d5545f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Stamen Toner 맵

# %%
seoul_map3 = folium.Map(location=[37.55, 126.98],tiles='Stamen Toner' ,zoom_start=12) # 은 흑백 스타일로 도로망을 강조
seoul_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0377dc944ac2508b224060a0d29d6a04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0377dc944ac2508b224060a0d29d6a04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0377dc944ac2508b224060a0d29d6a04 = L.map(
#                 &quot;map_0377dc944ac2508b224060a0d29d6a04&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68e0650a74219aff147656b619b534d6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0377dc944ac2508b224060a0d29d6a04);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 서울지역 대학교 위치

# %% [markdown]
# ## 지도에 Marker 표시

# %%
import pandas as pd

# %%
df = pd.read_excel('./sample/서울지역 대학교 위치.xlsx',engine='openpyxl')
df.head()
# Out:
#      Unnamed: 0         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
seoul_map = folium.Map(location = [37.55, 126.98], tiles='Stamen Terrain', zoom_start = 12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abd186ea84f21e2c9839770cbc104093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abd186ea84f21e2c9839770cbc104093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_abd186ea84f21e2c9839770cbc104093 = L.map(
#                 &quot;map_abd186ea84f21e2c9839770cbc104093&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84c1b6a728844b7e781bf486fd7afc23 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat, lng], popup = name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abd186ea84f21e2c9839770cbc104093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abd186ea84f21e2c9839770cbc104093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_abd186ea84f21e2c9839770cbc104093 = L.map(
#                 &quot;map_abd186ea84f21e2c9839770cbc104093&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84c1b6a728844b7e781bf486fd7afc23 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#             var marker_018bce4f0ced987441cef74a801ec309 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#         var popup_f0d9aa14dc0156f452bc503823deb1fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ecf24ec7842d924d1d7e8fb319d852df = $(`&lt;div id=&quot;html_ecf24ec7842d924d1d7e8fb319d852df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_f0d9aa14dc0156f452bc503823deb1fc.setContent(html_ecf24ec7842d924d1d7e8fb319d852df);
#
#
#         marker_018bce4f0ced987441cef74a801ec309.bindPopup(popup_f0d9aa14dc0156f452bc503823deb1fc)
#         ;
#
#
#
#
#             var marker_52202a2c3be899a8a90606ba1bd117e7 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#         var popup_3020bb6a04535371f576098f84f5a2a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_efe915eaa50bfac9359ceec34596ac3e = $(`&lt;div id=&quot;html_efe915eaa50bfac9359ceec34596ac3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_3020bb6a04535371f576098f84f5a2a8.setContent(html_efe915eaa50bfac9359ceec34596ac3e);
#
#
#         marker_52202a2c3be899a8a90606ba1bd117e7.bindPopup(popup_3020bb6a04535371f576098f84f5a2a8)
#         ;
#
#
#
#
#             var marker_b98e4b7097b09c976945c4e27d20ab61 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#         var popup_ef4cbd288d2de32c120283231355c37e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4a76581846a6d93d5342192196f86c6b = $(`&lt;div id=&quot;html_4a76581846a6d93d5342192196f86c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_ef4cbd288d2de32c120283231355c37e.setContent(html_4a76581846a6d93d5342192196f86c6b);
#
#
#         marker_b98e4b7097b09c976945c4e27d20ab61.bindPopup(popup_ef4cbd288d2de32c120283231355c37e)
#         ;
#
#
#
#
#             var marker_dee74d2970a613bb75818d2d081b33ab = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#         var popup_36d93f421e500d0393ead4ebee715fec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_60dac3347d1585f227bce788791eacf1 = $(`&lt;div id=&quot;html_60dac3347d1585f227bce788791eacf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#             popup_36d93f421e500d0393ead4ebee715fec.setContent(html_60dac3347d1585f227bce788791eacf1);
#
#
#         marker_dee74d2970a613bb75818d2d081b33ab.bindPopup(popup_36d93f421e500d0393ead4ebee715fec)
#         ;
#
#
#
#
#             var marker_e54b4f63be4f5ac6dcb0270669f37b8b = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#         var popup_e2f3bd296b78746f32f38fb19affc559 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8c2601d460830c90291e670a2fa9637f = $(`&lt;div id=&quot;html_8c2601d460830c90291e670a2fa9637f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#             popup_e2f3bd296b78746f32f38fb19affc559.setContent(html_8c2601d460830c90291e670a2fa9637f);
#
#
#         marker_e54b4f63be4f5ac6dcb0270669f37b8b.bindPopup(popup_e2f3bd296b78746f32f38fb19affc559)
#         ;
#
#
#
#
#             var marker_e672c820c2a9b49cdfb43cdf3f60d8bb = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_abd186ea84f21e2c9839770cbc104093);
#
#
#         var popup_c7b2ec75b85ad0869ebb8ab47346ca5c = L.popup(

# %% [markdown]
# ## 속성 변환

# %%
seoul_map = folium.Map(location = [37.55, 126.98], tiles='Stamen Terrain', zoom_start = 12)

for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                  radius = 10,
                  color = 'brown',
                  fill = True,
                  fill_color = 'coral',
                  fill_opacity = 0.7,
                  popup = name,
                 ).add_to(seoul_map)
    
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88910fe0c031012be2381502b3c4daa7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88910fe0c031012be2381502b3c4daa7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_88910fe0c031012be2381502b3c4daa7 = L.map(
#                 &quot;map_88910fe0c031012be2381502b3c4daa7&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59d74dbeb3fb9991852bd0b3e1c36e57 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88910fe0c031012be2381502b3c4daa7);
#
#
#             var circle_marker_9449629cd75ac521f2ce703845719815 = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88910fe0c031012be2381502b3c4daa7);
#
#
#         var popup_b8f2bc8d631340d49113c827bb10b1fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1aca2924460afbf7fb5f7b0c23020738 = $(`&lt;div id=&quot;html_1aca2924460afbf7fb5f7b0c23020738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_b8f2bc8d631340d49113c827bb10b1fa.setContent(html_1aca2924460afbf7fb5f7b0c23020738);
#
#
#         circle_marker_9449629cd75ac521f2ce703845719815.bindPopup(popup_b8f2bc8d631340d49113c827bb10b1fa)
#         ;
#
#
#
#
#             var circle_marker_35bbacd4570473bfb4079a2cfe817a02 = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88910fe0c031012be2381502b3c4daa7);
#
#
#         var popup_7efe9263496eb53820b4eaefa533e26b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a0ed4f09368740242e08ad6010fc4acb = $(`&lt;div id=&quot;html_a0ed4f09368740242e08ad6010fc4acb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_7efe9263496eb53820b4eaefa533e26b.setContent(html_a0ed4f09368740242e08ad6010fc4acb);
#
#
#         circle_marker_35bbacd4570473bfb4079a2cfe817a02.bindPopup(popup_7efe9263496eb53820b4eaefa533e26b)
#         ;
#
#
#
#
#             var circle_marker_55cc0fa50869ec89583698568ee781f7 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88910fe0c031012be2381502b3c4daa7);
#
#
#         var popup_6cd8296556ead6482aa549208bc000bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d17d9f1644790bd6863ee3f498c3dd86 = $(`&lt;div id=&quot;html_d17d9f1644790bd6863ee3f498c3dd86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_6cd8296556ead6482aa549208bc000bf.setContent(html_d17d9f1644790bd6863ee3f498c3dd86);
#
#
#         circle_marker_55cc0fa50869ec89583698568ee781f7.bindPopup(popup_6cd8296556ead6482aa549208bc000bf)
#         ;
#
#
#
#
#             var circle_marker_efb47f1e5970119ddedc8e4b602b3d55 = L.circleMarker(
#                 [37.4996227, 127.0060653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;

# %% [markdown]
# # 지도 영역에 단계구분도(Choropleth Map) 표시

# %%
import json

# %%
df = pd.read_excel('./sample/경기도인구데이터.xlsx', index_col='구분', engine='openpyxl')
df.columns = df.columns.map(str)
df.head()
# Out:
#           2007    2008    2009    2010    2011    2012    2013    2014  \
# 구분
# 수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
#
#           2015    2016    2017
# 구분
# 수원시장안구  299016  296479  293828
# 수원시권선구  351053  358393  365653
# 수원시팔달구  199180  198515  193311
# 수원시영통구  335375  340654  349836
# 성남시수정구  219531  232841  236932

# %%
geo_path = './sample/경기도행정구역경계.json'
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))

g_map = folium.Map(location=[37.5502,126.982], titles = 'Stamen Terrain', zoom_start=9)
year = '2017'

# %%
# # Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,
                  data = df['2007'],
                  columns=[df.index, df[year]],
                  fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                  threshold_scale=[10000, 100000, 300000, 500000, 700000], 
                  key_on = 'feature.properties.name'
                 ).add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8309edc65a1d2bf0a37b8a277af80864 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8309edc65a1d2bf0a37b8a277af80864&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8309edc65a1d2bf0a37b8a277af80864 = L.map(
#                 &quot;map_8309edc65a1d2bf0a37b8a277af80864&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea16f86dd4abe50b4f5ffdd42961fab1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8309edc65a1d2bf0a37b8a277af80864);
#
#
#             var choropleth_8cbf5cae9a9d03e01698a7389dd618ec = L.featureGroup(
#                 {}
#             ).addTo(map_8309edc65a1d2bf0a37b8a277af80864);
#
#
#         function geo_json_94b2701bed69e5bafe818b4da838b98a_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31380: case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31200: case 31192: case 31150: case 31130: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31023: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_94b2701bed69e5bafe818b4da838b98a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_94b2701bed69e5bafe818b4da838b98a = L.geoJson(null, {
#                 onEachFeature: geo_json_94b2701bed69e5bafe818b4da838b98a_onEachFeature,
#
#                 style: geo_json_94b2701bed69e5bafe818b4da838b98a_styler,
#         });
#
#         function geo_json_94b2701bed69e5bafe818b4da838b98a_add (data) {
#             geo_json_94b2701bed69e5bafe818b4da838b98a
#                 .addData(data)
#                 .addTo(choropleth_8cbf5cae9a9d03e01698a7389dd618ec);
#         }
#             geo_json_94b2701bed69e5bafe818b4da838b98a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.39174400683049, 37.4256483411369], [127.40276739880215, 37.41856433413549], [127.4250053080982, 37.43669952587185], [127.4817900304572, 37.42084413829662], [127.51015267026155, 37.43699555518635], [127.52501209957308, 37.43192043868044], [127.53910572062166, 37.40849283821634], [127.60528700481163, 37.416969769508924], [127.63754040237271, 37.41065607591271], [127.6491838950862, 37.402042953108506], [127.66976823475012, 37.40884431255766], [127.71071536074867, 37.40736583858037], [127.70347417929173, 37.371054026073324], [127.76165381178268, 37.36421926003675], [127.77952402154285, 37.368441789396854], [127.80397287036232, 37.432516049235865], [127.79833492163134, 37.460500237870505], [127.77664798308412, 37.48883635932707], [127.77611527652192, 37.50328615763377], [127.80855972024105, 37.53220450961153], [127.8445769305193, 37.53621789699497], [127.85162286006927, 37.55037340096326], [127.81507964099751, 37.5618389022189], [127.79492564827493, 37.58252978378627], [127.76838776707211, 37.580178216134605], [127.75614914198108, 37.589477424718204], [127.7102810556826, 37.58360128682645], [127.69869383868397, 37.59757031454811], [127.65553070991882, 37.61954565135447], [127.62972032693943, 37.63983122973888], [127.60450569091653, 37.648548552427314], [127.5816670144209

# %%
# # Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,
                  data = df[year],
                  columns=[df.index, df[year]],
                  fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                  threshold_scale=[10000, 100000, 300000, 500000, 700000], 
                  key_on = 'feature.properties.name'
                 ).add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8309edc65a1d2bf0a37b8a277af80864 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8309edc65a1d2bf0a37b8a277af80864&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8309edc65a1d2bf0a37b8a277af80864 = L.map(
#                 &quot;map_8309edc65a1d2bf0a37b8a277af80864&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea16f86dd4abe50b4f5ffdd42961fab1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8309edc65a1d2bf0a37b8a277af80864);
#
#
#             var choropleth_8cbf5cae9a9d03e01698a7389dd618ec = L.featureGroup(
#                 {}
#             ).addTo(map_8309edc65a1d2bf0a37b8a277af80864);
#
#
#         function geo_json_94b2701bed69e5bafe818b4da838b98a_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31380: case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31200: case 31192: case 31150: case 31130: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31023: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_94b2701bed69e5bafe818b4da838b98a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_94b2701bed69e5bafe818b4da838b98a = L.geoJson(null, {
#                 onEachFeature: geo_json_94b2701bed69e5bafe818b4da838b98a_onEachFeature,
#
#                 style: geo_json_94b2701bed69e5bafe818b4da838b98a_styler,
#         });
#
#         function geo_json_94b2701bed69e5bafe818b4da838b98a_add (data) {
#             geo_json_94b2701bed69e5bafe818b4da838b98a
#                 .addData(data)
#                 .addTo(choropleth_8cbf5cae9a9d03e01698a7389dd618ec);
#         }
#             geo_json_94b2701bed69e5bafe818b4da838b98a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.39174400683049, 37.4256483411369], [127.40276739880215, 37.41856433413549], [127.4250053080982, 37.43669952587185], [127.4817900304572, 37.42084413829662], [127.51015267026155, 37.43699555518635], [127.52501209957308, 37.43192043868044], [127.53910572062166, 37.40849283821634], [127.60528700481163, 37.416969769508924], [127.63754040237271, 37.41065607591271], [127.6491838950862, 37.402042953108506], [127.66976823475012, 37.40884431255766], [127.71071536074867, 37.40736583858037], [127.70347417929173, 37.371054026073324], [127.76165381178268, 37.36421926003675], [127.77952402154285, 37.368441789396854], [127.80397287036232, 37.432516049235865], [127.79833492163134, 37.460500237870505], [127.77664798308412, 37.48883635932707], [127.77611527652192, 37.50328615763377], [127.80855972024105, 37.53220450961153], [127.8445769305193, 37.53621789699497], [127.85162286006927, 37.55037340096326], [127.81507964099751, 37.5618389022189], [127.79492564827493, 37.58252978378627], [127.76838776707211, 37.580178216134605], [127.75614914198108, 37.589477424718204], [127.7102810556826, 37.58360128682645], [127.69869383868397, 37.59757031454811], [127.65553070991882, 37.61954565135447], [127.62972032693943, 37.63983122973888], [127.60450569091653, 37.648548552427314], [127.5816670144209

# %% [markdown]
# 2007년과 비교하면 남양주, 분당, 화성(동탄) 지역의 신도시 개발과 인구 유입으로인구가 집중되는 현상이 심화된 것을 볼 수 있다.

# %% [markdown]
# # 공공 데이터 활용

# %%
df = pd.read_csv('./sample/서울시 응급실 위치 정보.csv', encoding='cp949')
df
# Out:
#         기관ID                                     주소 병원분류 병원분류명 응급의료기관코드  \
# 0   A1100008        서울특별시 성북구 고려대로 73 고려대병원 (안암동5가)    A  종합병원     G001
# 1   A1100011       서울특별시 영등포구 63로 10 여의도성모병원 (여의도동)    A  종합병원     G006
# 2   A1121013               서울특별시 은평구 통일로 1021 (진관동)    A  종합병원     G006
# 3   A1100047                서울특별시 관악구 관악로 242 (봉천동)    B    병원     G009
# 4   A1100076       서울특별시 관악구 남부순환로 1449 (신림동 서울본병원)    B    병원     G009
# ..       ...                                    ...  ...   ...      ...
# 63  A1100038  서울특별시 영등포구 버드나루로7길 12 (영등포동7가 한강성심병원)    A  종합병원     G009
# 64  A1100013             서울특별시 성동구 왕십리로 222-1 (사근동)    A  종합병원     G001
# 65  A1100051                 서울특별시 광진구 자양로 85 (자양동)    A  종합병원     G007
# 66  A1100019         서울특별시 양천구 목동로 225 홍익병원본관 (신정동)    A  종합병원     G007
# 67  A1100049               서울특별시 금천구 시흥대로 244 (시흥동)    A  종합병원     G007
#
#     응급의료기관코드명  응급실운영여부                                                 비고  \
# 0    권역응급의료센터        1                                         토요일 25째 휴무
# 1    지역응급의료센터        1                                      일요일은 교정진료만 운영
# 2    지역응급의료센터        1                                      일요일은 교정진료만 운영
# 3   응급실운영신고기관        1  접수는 평일 16시 토요일은 12시전까지만 가능합니다.  공휴일은 요일에 맞춰 진료...
# 4   응급실운영신고기관        1                                   점심시간 12:30~13:30
# ..        ...      ...                                                ...
# 63  응급실운영신고기관        1                             진료과에따라 상이함(연락 후 내원 바람)
# 64   권역응급의료센터        1                                      점심시간: 13시~14시
# 65   지역응급의료기관        1                                   점심시간 13:00~14:00
# 66   지역응급의료기관        1                          평일 30분전 접수마감 토요일 13시 접수마감
# 67   지역응급의료기관        1                                   점심시간 12:00-13:00
#
#                                  기관설명상세  \
# 0                       건강검진센터 내과진료만 가능
# 1                소아과 평일) 9-18시 토) 9-14시
# 2                소아과 평일) 9-18시 토) 9-14시
# 3           점심시간 : 오후 1시-오후 2시 전화 예약 가능
# 4         관악구 봉천동 187병상 투석 가능한 요양병원입니다.
# ..                                  ...
# 63                       점심 12:30~13:30
# 64                         관절염/류마티스 전문/
# 65  24시간 전문의 진료가 가능한 서울 동북부 지역 거점병원입니다.
# 66                         후두내시경O/수액처치O
# 67                            24째 토요일휴진
#
#                                       간이약도  ... 진료시간(목요일)S 진료시간(금요일)S  \
# 0            지하철 6호선 안암역 하차 후 1번출구 도보 500m  ...        900        900
# 1                                샛강역 3번 출구  ...        900        900
# 2                                샛강역 3번 출구  ...        830        830
# 3                       서울대입구역 7번 출구 도보 5분  ...        900        900
# 4                        2호선 신대방역/난곡사거리 인근  ...        900        900
# ..                                     ...  ...        ...        ...
# 63  서울특별시 영등포구 버드나루로7길 12 (영등포동 7가 94-200)  ...        900        900
# 64                              한양대역 1번 출구  ...        900        900
# 65                 2호선 구의역 4번출구 직진방향 5분 거리  ...        830        830
# 66                               목동역 2번 출구  ...        900        900
# 67                             금천구청역 1번 출구  ...        830        830
#
#    진료시간(토요일)S  진료시간(일요일)S  진료시간(공휴일)S  우편번호1  우편번호2        병원경도       병원위도  \
# 0         900         900         900     28     41  127.026471  37.587156
# 1         900        1000           0     73     45  126.936731  37.518272
# 2         830        1000           0     33     12  126.916150  37.633608
# 3         900        1000         900     87     35  126.956781  37.485618
# 4         900        1000         900     87     67  126.911708  37.481585
# ..        ...         ...         ...    ...    ...         ...        ...
# 63        830        1000        1000     72     47  126.910330  37.523467
# 64        900         930         900     47     63  127.044883  37.559945
# 65        830         900         900     50     56  127.083601  37.535316
# 66        900        1000        1000     79     37  126.863664  37.528441
# 67        830        1000        1000     86     26  126.900563  37.455671
#
#                      작업시간
# 0   2022-07-07 14:55:07.0
# 1   2022-07-07 14:55:08.0
# 2   2022-07-07 14:55:08.0
# 3   2022-07-07 14:55:08.0
# 4   2022-07-07 14:55:08.0
# ..                    ...
# 63  2022-07-07 14:55:35.0
# 64  2022-07-07 14:55:35.0
# 65  2022-07-07 14:55:36.0
# 66  2022-07-07 14:55:36.0
# 67  2022-07-07 14:55:37.0
#
# [68 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['기관ID', '주소', '병원분류', '병원분류명', '응급의료기관코드', '응급의료기관코드명', '응급실운영여부', '비고',
#        '기관설명상세', '간이약도', '기관명', '대표전화1', '응급실전화', '진료시간(월요일)C', '진료시간(화요일)C',
#        '진료시간(수요일)C', '진료시간(목요일)C', '진료시간(금요일)C', '진료시간(토요일)C', '진료시간(일요일)C',
#        '진료시간(공휴일)C', '진료시간(월요일)S', '진료시간(화요일)S', '진료시간(수요일)S', '진료시간(목요일)S',
#        '진료시간(금요일)S', '진료시간(토요일)S', '진료시간(일요일)S', '진료시간(공휴일)S', '우편번호1',
#        '우편번호2', '병원경도', '병원위도', '작업시간'],
#       dtype='object')

# %%
seoul_map = folium.Map(location= [37.55, 126.98], zoom_start=12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef6dcd9a4b4224e96fe0b519831cb265 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef6dcd9a4b4224e96fe0b519831cb265&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ef6dcd9a4b4224e96fe0b519831cb265 = L.map(
#                 &quot;map_ef6dcd9a4b4224e96fe0b519831cb265&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ea30037f8b463a1f644fbb832e8ace2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for name, lat, lng in zip(df.병원분류명, df.병원위도, df.병원경도):
    folium.Marker([lat, lng], popup = name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef6dcd9a4b4224e96fe0b519831cb265 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef6dcd9a4b4224e96fe0b519831cb265&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ef6dcd9a4b4224e96fe0b519831cb265 = L.map(
#                 &quot;map_ef6dcd9a4b4224e96fe0b519831cb265&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ea30037f8b463a1f644fbb832e8ace2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#             var marker_bec7e65a0eafc31ed5c4a6fbd263aa06 = L.marker(
#                 [37.58715608002366, 127.02647086385966],
#                 {}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#         var popup_785f2bdaa29967c9b33cc5959d86d621 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a17be143438ee26f0a3c2d1511329cb3 = $(`&lt;div id=&quot;html_a17be143438ee26f0a3c2d1511329cb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종합병원&lt;/div&gt;`)[0];
#             popup_785f2bdaa29967c9b33cc5959d86d621.setContent(html_a17be143438ee26f0a3c2d1511329cb3);
#
#
#         marker_bec7e65a0eafc31ed5c4a6fbd263aa06.bindPopup(popup_785f2bdaa29967c9b33cc5959d86d621)
#         ;
#
#
#
#
#             var marker_2c3ee62dc7eb8bd222c43bf32bd11ac5 = L.marker(
#                 [37.51827233800711, 126.93673129599132],
#                 {}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#         var popup_2abe02867b6448902e07446874c6009b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_32c46a7017cfa0e0fb1bb7ec9f745610 = $(`&lt;div id=&quot;html_32c46a7017cfa0e0fb1bb7ec9f745610&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종합병원&lt;/div&gt;`)[0];
#             popup_2abe02867b6448902e07446874c6009b.setContent(html_32c46a7017cfa0e0fb1bb7ec9f745610);
#
#
#         marker_2c3ee62dc7eb8bd222c43bf32bd11ac5.bindPopup(popup_2abe02867b6448902e07446874c6009b)
#         ;
#
#
#
#
#             var marker_46e5699f362db73074e25b2a4e69afa2 = L.marker(
#                 [37.63360840972685, 126.91615048739686],
#                 {}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#         var popup_d2e38504150bba5715853d28e6ce34e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a187007e501430c30fb6e95eea6fb176 = $(`&lt;div id=&quot;html_a187007e501430c30fb6e95eea6fb176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종합병원&lt;/div&gt;`)[0];
#             popup_d2e38504150bba5715853d28e6ce34e7.setContent(html_a187007e501430c30fb6e95eea6fb176);
#
#
#         marker_46e5699f362db73074e25b2a4e69afa2.bindPopup(popup_d2e38504150bba5715853d28e6ce34e7)
#         ;
#
#
#
#
#             var marker_3c898c379e94c0d1b8b9e87225d91a1e = L.marker(
#                 [37.485618115306, 126.95678091199277],
#                 {}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#         var popup_5256c1d310e32784bb90c7917f8cf83d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c7134f40800212bca6007a7ba411874b = $(`&lt;div id=&quot;html_c7134f40800212bca6007a7ba411874b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;병원&lt;/div&gt;`)[0];
#             popup_5256c1d310e32784bb90c7917f8cf83d.setContent(html_c7134f40800212bca6007a7ba411874b);
#
#
#         marker_3c898c379e94c0d1b8b9e87225d91a1e.bindPopup(popup_5256c1d310e32784bb90c7917f8cf83d)
#         ;
#
#
#
#
#             var marker_afc956f2a44f03503302785cda3b7e18 = L.marker(
#                 [37.4815853446168, 126.9117077397649],
#                 {}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#         var popup_52905303e92b406fafec0cf1a7f6ef30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2275bd1d9316970ca813cfdfe582c51f = $(`&lt;div id=&quot;html_2275bd1d9316970ca813cfdfe582c51f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;병원&lt;/div&gt;`)[0];
#             popup_52905303e92b406fafec0cf1a7f6ef30.setContent(html_2275bd1d9316970ca813cfdfe582c51f);
#
#
#         marker_afc956f2a44f03503302785cda3b7e18.bindPopup(popup_52905303e92b406fafec0cf1a7f6ef30)
#         ;
#
#
#
#
#             var marker_90e49d1a4329a0ebb5ac450d6b4b9302 = L.marker(
#                 [37.55347640402066, 127.15752179822285],
#                 {}
#             ).addTo(map_ef6dcd9a4b4224e96fe0b519831cb265);
#
#
#         var popup_fc5fbfcf168bdec6a458f4c46c2d72de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_74ca51b131fc8ae77141a67419fdb1ad = $(`&lt;div id=&quot;
