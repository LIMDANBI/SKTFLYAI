# %% [markdown]
# # 데이터 분석

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 한글 폰트 깨짐 방지
if os.name == 'posix':
    plt.rc("font", family="AppleGothic.ttf")

else:
    plt.rc("font", family="Malgun Gothic")

# %%
df = pd.read_csv('./wildfireDataset.csv')
df.head()
# Out:
#    일련번호  인명피해수  재산피해금액   소방서명        서센터명    소방지역대명    화재발생일자  화재발생시간  \
# 0     1      0       0  강릉소방서   경포119안전센터       NaN  20110122  233500
# 1     2      0  184330  양양소방서  하조대119안전센터       NaN  20110131  181300
# 2     3      0       0  강릉소방서   경포119안전센터       NaN  20110201  210700
# 3     4      0    4864  홍천소방서   서석119안전센터  내촌119지역대  20110211  175000
# 4     5      0      50  원주소방서   흥업119안전센터  귀래119지역대  20110212   61800
#
#        접수일자    접수시각  ...   발화원인  발화요인대분류명  전체인력수합계  동원장비수    날씨   온도   습도  \
# 0  20110122  233511  ...     기타      방화의심       37      8    맑음 -1.0   30
# 1  20110131  181311  ...     기타       부주의     1872     71    맑음  1.0   10
# 2  20110201  210710  ...     기타      방화의심      184     15    맑음  1.0  550
# 3  20110211  175032  ...  입산자실화        기타      171      9  구름많음 -2.0   29
# 4  20110212   61836  ...    모닥불       부주의       94      9  구름많음 -6.0   44
#
#    시간단위풍속  시간단위풍향  특보내용
# 0    45.0     8.0   NaN
# 1   225.0     8.0  건조경보
# 2   135.0     4.0   NaN
# 3   225.0     4.0   NaN
# 4   225.0     4.0   NaN
#
# [5 rows x 38 columns]

# %%
df.dtypes
# Out:
# 일련번호           int64
# 인명피해수          int64
# 재산피해금액         int64
# 소방서명          object
# 서센터명          object
# 소방지역대명        object
# 화재발생일자         int64
# 화재발생시간         int64
# 접수일자           int64
# 접수시각           int64
# 출동일자           int64
# 출동시각           int64
# 현장도착일자         int64
# 현장도착시각         int64
# 초진일자           int64
# 초진시각           int64
# 완진일자           int64
# 완진시간           int64
# 출동소요시간         int64
# 화재진압시간         int64
# 현장소방서거리        int64
# 현장안전센터거리       int64
# 현장소방지역대거리    float64
# 시군구명          object
# 읍면동명          object
# 시설장소소분류명      object
# 화재유형명         object
# 발화지점          object
# 발화원인          object
# 발화요인대분류명      object
# 전체인력수합계        int64
# 동원장비수          int64
# 날씨            object
# 온도           float64
# 습도             int64
# 시간단위풍속       float64
# 시간단위풍향       float64
# 특보내용          object
# dtype: object

# %% [markdown]
# ## 출동시간에 따른 화재진압시간(피해규모)
#
# 가정 1 : 출동시간이 빠르면 화재진압시간이 더 빠를 것이다.<br>
# 가정 2 : 출동시간이 빠르면 재산피해금액이 더 적을 것이다.<br>
# 가정 3 : 출동시간이 빠르면 인명피해수가 더 적을 것이다.<br>
#
# 15시 59분 52초 => 15*60+59 = 959분 식으로 바꿔서 분석을 진행했다.
# (초 단위를 959.52 이런 식으로 넣으려다가 애매해서 우선 생략했다.)

# %%
df['화재진압시간']
# Out:
# 0         1800
# 1       155952
# 2        12300
# 3        20500
# 4        35009
#          ...
# 1048      4529
# 1049     43459
# 1050     15226
# 1051     12539
# 1052     12515
# Name: 화재진압시간, Length: 1053, dtype: int64

# %%
df['화재진압시간'].max()
# Out:
# 235419

# %%
df['화재진압시간_h'] = df['화재진압시간']//10000
df['화재진압시간_m'] = df['화재진압시간']//100-df['화재진압시간_h']*100
df['화재진압시간(분)'] = df['화재진압시간_h']*60+df['화재진압시간_m']
df
# Out:
#       일련번호  인명피해수  재산피해금액   소방서명        서센터명    소방지역대명    화재발생일자  화재발생시간  \
# 0        1      0       0  강릉소방서   경포119안전센터       NaN  20110122  233500
# 1        2      0  184330  양양소방서  하조대119안전센터       NaN  20110131  181300
# 2        3      0       0  강릉소방서   경포119안전센터       NaN  20110201  210700
# 3        4      0    4864  홍천소방서   서석119안전센터  내촌119지역대  20110211  175000
# 4        5      0      50  원주소방서   흥업119안전센터  귀래119지역대  20110212   61800
# ...    ...    ...     ...    ...         ...       ...       ...     ...
# 1048    42      0       0  철원소방서   동송119안전센터       NaN  20210509  174449
# 1049    43      0       0  태백소방서   화전119안전센터       NaN  20210513  153705
# 1050    44      0       0  횡성소방서   우천119안전센터     안흥지역대  20210514  115006
# 1051    45      0     223  강릉소방서  주문진119안전센터       NaN  20210607  151139
# 1052    46      0       0  홍천소방서   서석119안전센터  내촌119지역대  20210608  145246
#
#           접수일자    접수시각  ...  동원장비수    날씨    온도   습도  시간단위풍속  시간단위풍향  특보내용  \
# 0     20110122  233511  ...      8    맑음  -1.0   30    45.0     8.0   NaN
# 1     20110131  181311  ...     71    맑음   1.0   10   225.0     8.0  건조경보
# 2     20110201  210710  ...     15    맑음   1.0  550   135.0     4.0   NaN
# 3     20110211  175032  ...      9  구름많음  -2.0   29   225.0     4.0   NaN
# 4     20110212   61836  ...      9  구름많음  -6.0   44   225.0     4.0   NaN
# ...        ...     ...  ...    ...   ...   ...  ...     ...     ...   ...
# 1048  20210509  174400  ...     13    맑음  18.0   22   270.0     8.0   NaN
# 1049  20210513  153700  ...     18    맑음  23.0   43    45.0     4.0   NaN
# 1050  20210514  115000  ...     18    맑음  24.0   58     0.0     4.0   NaN
# 1051  20210607  151100  ...     11    맑음  25.0   62   225.0     4.0   NaN
# 1052  20210608  145200  ...      6    맑음  18.0   78    45.0     4.0   NaN
#
#       화재진압시간_h  화재진압시간_m  화재진압시간(분)
# 0            0        18         18
# 1           15        59        959
# 2            1        23         83
# 3            2         5        125
# 4            3        50        230
# ...        ...       ...        ...
# 1048         0        45         45
# 1049         4        34        274
# 1050         1        52        112
# 1051         1        25         85
# 1052         1        25         85
#
# [1053 rows x 41 columns]

# %%
df.drop(['화재진압시간','화재진압시간_h', '화재진압시간_m'], axis=1, inplace=True)
df
# Out:
#       일련번호  인명피해수  재산피해금액   소방서명        서센터명    소방지역대명    화재발생일자  화재발생시간  \
# 0        1      0       0  강릉소방서   경포119안전센터       NaN  20110122  233500
# 1        2      0  184330  양양소방서  하조대119안전센터       NaN  20110131  181300
# 2        3      0       0  강릉소방서   경포119안전센터       NaN  20110201  210700
# 3        4      0    4864  홍천소방서   서석119안전센터  내촌119지역대  20110211  175000
# 4        5      0      50  원주소방서   흥업119안전센터  귀래119지역대  20110212   61800
# ...    ...    ...     ...    ...         ...       ...       ...     ...
# 1048    42      0       0  철원소방서   동송119안전센터       NaN  20210509  174449
# 1049    43      0       0  태백소방서   화전119안전센터       NaN  20210513  153705
# 1050    44      0       0  횡성소방서   우천119안전센터     안흥지역대  20210514  115006
# 1051    45      0     223  강릉소방서  주문진119안전센터       NaN  20210607  151139
# 1052    46      0       0  홍천소방서   서석119안전센터  내촌119지역대  20210608  145246
#
#           접수일자    접수시각  ...  발화요인대분류명  전체인력수합계  동원장비수    날씨    온도   습도  \
# 0     20110122  233511  ...      방화의심       37      8    맑음  -1.0   30
# 1     20110131  181311  ...       부주의     1872     71    맑음   1.0   10
# 2     20110201  210710  ...      방화의심      184     15    맑음   1.0  550
# 3     20110211  175032  ...        기타      171      9  구름많음  -2.0   29
# 4     20110212   61836  ...       부주의       94      9  구름많음  -6.0   44
# ...        ...     ...  ...       ...      ...    ...   ...   ...  ...
# 1048  20210509  174400  ...       부주의       67     13    맑음  18.0   22
# 1049  20210513  153700  ...     기계적요인      144     18    맑음  23.0   43
# 1050  20210514  115000  ...     전기적요인      131     18    맑음  24.0   58
# 1051  20210607  151100  ...       부주의       50     11    맑음  25.0   62
# 1052  20210608  145200  ...    자연적인요인       48      6    맑음  18.0   78
#
#       시간단위풍속  시간단위풍향  특보내용  화재진압시간(분)
# 0       45.0     8.0   NaN         18
# 1      225.0     8.0  건조경보        959
# 2      135.0     4.0   NaN         83
# 3      225.0     4.0   NaN        125
# 4      225.0     4.0   NaN        230
# ...      ...     ...   ...        ...
# 1048   270.0     8.0   NaN         45
# 1049    45.0     4.0   NaN        274
# 1050     0.0     4.0   NaN        112
# 1051   225.0     4.0   NaN         85
# 1052    45.0     4.0   NaN         85
#
# [1053 rows x 38 columns]

# %%
df['출동소요시간'].max()
# Out:
# 5840

# %%
df['출동소요시간(분)'] = df['출동소요시간']//100
df.drop('출동소요시간', axis=1, inplace=True)
df
# Out:
#       일련번호  인명피해수  재산피해금액   소방서명        서센터명    소방지역대명    화재발생일자  화재발생시간  \
# 0        1      0       0  강릉소방서   경포119안전센터       NaN  20110122  233500
# 1        2      0  184330  양양소방서  하조대119안전센터       NaN  20110131  181300
# 2        3      0       0  강릉소방서   경포119안전센터       NaN  20110201  210700
# 3        4      0    4864  홍천소방서   서석119안전센터  내촌119지역대  20110211  175000
# 4        5      0      50  원주소방서   흥업119안전센터  귀래119지역대  20110212   61800
# ...    ...    ...     ...    ...         ...       ...       ...     ...
# 1048    42      0       0  철원소방서   동송119안전센터       NaN  20210509  174449
# 1049    43      0       0  태백소방서   화전119안전센터       NaN  20210513  153705
# 1050    44      0       0  횡성소방서   우천119안전센터     안흥지역대  20210514  115006
# 1051    45      0     223  강릉소방서  주문진119안전센터       NaN  20210607  151139
# 1052    46      0       0  홍천소방서   서석119안전센터  내촌119지역대  20210608  145246
#
#           접수일자    접수시각  ...  전체인력수합계  동원장비수    날씨    온도   습도  시간단위풍속  시간단위풍향  \
# 0     20110122  233511  ...       37      8    맑음  -1.0   30    45.0     8.0
# 1     20110131  181311  ...     1872     71    맑음   1.0   10   225.0     8.0
# 2     20110201  210710  ...      184     15    맑음   1.0  550   135.0     4.0
# 3     20110211  175032  ...      171      9  구름많음  -2.0   29   225.0     4.0
# 4     20110212   61836  ...       94      9  구름많음  -6.0   44   225.0     4.0
# ...        ...     ...  ...      ...    ...   ...   ...  ...     ...     ...
# 1048  20210509  174400  ...       67     13    맑음  18.0   22   270.0     8.0
# 1049  20210513  153700  ...      144     18    맑음  23.0   43    45.0     4.0
# 1050  20210514  115000  ...      131     18    맑음  24.0   58     0.0     4.0
# 1051  20210607  151100  ...       50     11    맑음  25.0   62   225.0     4.0
# 1052  20210608  145200  ...       48      6    맑음  18.0   78    45.0     4.0
#
#       특보내용  화재진압시간(분)  출동소요시간(분)
# 0      NaN         18         17
# 1     건조경보        959         16
# 2      NaN         83          6
# 3      NaN        125         22
# 4      NaN        230         20
# ...    ...        ...        ...
# 1048   NaN         45          3
# 1049   NaN        274         21
# 1050   NaN        112         12
# 1051   NaN         85         13
# 1052   NaN         85          9
#
# [1053 rows x 38 columns]

# %%
# plt.style.use('seaborn-whitegrid')
# fig = plt.figure(figsize=(10, 4))
# ax = fig.add_subplot(111)
# ax.set_title("출동소요시간(분)에 따른 화재진압시간(분)")
# ax.scatter(df['출동소요시간(분)'], df['화재진압시간(분)'], alpha=0.3)
# plt.show()
