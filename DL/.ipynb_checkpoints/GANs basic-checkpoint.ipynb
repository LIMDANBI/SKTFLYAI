# %% [markdown]
# # GANs

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D

# %% [markdown]
# ## GPU 설정

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %% [markdown]
# ## 생성자 Model (G)

# %%
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %% [markdown]
# ## 판별자 Model (D)

# %%
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %% [markdown]
# ## 생성자와 판별자 모델 연결

# %%
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
def gan_train(epoch, batch_size, saving_interval):

    (X_train, _), (_, _) = mnist.load_data()
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')

    X_train = (X_train - 127.5) / 127.5

    true = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    for i in range(epoch):
        
        # 실제 데이터를 판별자에 입력
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]
        d_loss_real = discriminator.train_on_batch(imgs, true)

        # 가상 이미지를 판별자에 입력
        noise = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(noise)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        # 판별자와 생성자의 오차 계산
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        g_loss = gan.train_on_batch(noise, true)

        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)
        
        if i % saving_interval == 0:
            # r, c = 5, 5
            noise = np.random.normal(0, 1, (25, 100))
            gen_imgs = generator.predict(noise)

            # Rescale images 0 - 1
            gen_imgs = 0.5 * gen_imgs + 0.5

            fig, axs = plt.subplots(5, 5)
            count = 0
            for j in range(5):
                for k in range(5):
                    axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                    axs[j, k].axis('off')
                    count += 1
            fig.savefig("gan_images/gan_mnist_%d.png" % i)

# %%
gan_train(2001, 32, 200)
# Out:
# epoch:0  d_loss:0.7286  g_loss:0.6105
# epoch:1  d_loss:0.4409  g_loss:0.2522
# epoch:2  d_loss:0.3960  g_loss:0.0273
# epoch:3  d_loss:0.5739  g_loss:0.0064
# epoch:4  d_loss:0.8016  g_loss:0.0094
# epoch:5  d_loss:0.7599  g_loss:0.0656
# epoch:6  d_loss:0.5687  g_loss:0.3571
# epoch:7  d_loss:0.5241  g_loss:0.6806
# epoch:8  d_loss:0.5734  g_loss:0.7846
# epoch:9  d_loss:0.5577  g_loss:0.7464
# epoch:10  d_loss:0.5203  g_loss:0.7143
# epoch:11  d_loss:0.4593  g_loss:0.6945
# epoch:12  d_loss:0.4220  g_loss:0.7019
# epoch:13  d_loss:0.3381  g_loss:0.8148
# epoch:14  d_loss:0.3184  g_loss:1.0289
# epoch:15  d_loss:0.2389  g_loss:1.2498
# epoch:16  d_loss:0.1928  g_loss:1.5221
# epoch:17  d_loss:0.1845  g_loss:1.5146
# epoch:18  d_loss:0.1971  g_loss:1.1614
# epoch:19  d_loss:0.3675  g_loss:1.0895
# epoch:20  d_loss:0.5107  g_loss:1.0430
# epoch:21  d_loss:0.8448  g_loss:0.8399
# epoch:22  d_loss:0.8984  g_loss:0.5518
# epoch:23  d_loss:0.5895  g_loss:0.7138
# epoch:24  d_loss:0.5876  g_loss:0.7574
# epoch:25  d_loss:0.7350  g_loss:0.7332
# epoch:26  d_loss:0.5284  g_loss:0.6954
# epoch:27  d_loss:0.5640  g_loss:0.6576
# epoch:28  d_loss:0.3976  g_loss:0.8638
# epoch:29  d_loss:0.4323  g_loss:0.8023
# epoch:30  d_loss:0.4099  g_loss:0.8163
# epoch:31  d_loss:0.4000  g_loss:0.8420
# epoch:32  d_loss:0.3660  g_loss:0.9069
# epoch:33  d_loss:0.4023  g_loss:0.8888
# epoch:34  d_loss:0.4545  g_loss:0.9936
# epoch:35  d_loss:0.3411  g_loss:1.0209
# epoch:36  d_loss:0.3249  g_loss:1.1926
# epoch:37  d_loss:0.3262  g_loss:1.3431
# epoch:38  d_loss:0.3422  g_loss:1.4587
# epoch:39  d_loss:0.3169  g_loss:1.3556
# epoch:40  d_loss:0.2847  g_loss:1.8721
# epoch:41  d_loss:0.2285  g_loss:2.3689
# epoch:42  d_loss:0.2282  g_loss:2.5838
# epoch:43  d_loss:0.2008  g_loss:2.5256
# epoch:44  d_loss:0.1873  g_loss:2.6558
# epoch:45  d_loss:0.1286  g_loss:3.3779
# epoch:46  d_loss:0.1630  g_loss:4.0417
# epoch:47  d_loss:0.1219  g_loss:3.8896
# epoch:48  d_loss:0.1460  g_loss:4.2044
# epoch:49  d_loss:0.1500  g_loss:5.0200
# epoch:50  d_loss:0.1329  g_loss:5.4603
# epoch:51  d_loss:0.1262  g_loss:5.0459
# epoch:52  d_loss:0.0923  g_loss:5.5259
# epoch:53  d_loss:0.1589  g_loss:5.5806
# epoch:54  d_loss:0.1090  g_loss:5.5877
# epoch:55  d_loss:0.1471  g_loss:4.7178
# epoch:56  d_loss:0.0847  g_loss:4.0321
# epoch:57  d_loss:0.1772  g_loss:3.4920
# epoch:58  d_loss:0.1924  g_loss:3.5990
# epoch:59  d_loss:0.2550  g_loss:2.8601
# epoch:60  d_loss:0.5871  g_loss:1.7169
# epoch:61  d_loss:0.3749  g_loss:1.5725
# epoch:62  d_loss:0.1595  g_loss:2.3010
# epoch:63  d_loss:0.0752  g_loss:3.1479
# epoch:64  d_loss:0.0853  g_loss:2.9142
# epoch:65  d_loss:0.0815  g_loss:2.9421
# epoch:66  d_loss:0.0669  g_loss:2.9117
# epoch:67  d_loss:0.1674  g_loss:2.7507
# epoch:68  d_loss:0.1124  g_loss:3.7284
# epoch:69  d_loss:0.0939  g_loss:5.0353
# epoch:70  d_loss:0.1852  g_loss:4.9832
# epoch:71  d_loss:0.3326  g_loss:3.3878
# epoch:72  d_loss:0.3618  g_loss:3.4358
# epoch:73  d_loss:0.5235  g_loss:4.3616
# epoch:74  d_loss:1.0257  g_loss:3.9361
# epoch:75  d_loss:1.0792  g_loss:2.5712
# epoch:76  d_loss:0.8140  g_loss:2.9129
# epoch:77  d_loss:0.6775  g_loss:3.2579
# epoch:78  d_loss:0.4581  g_loss:2.9469
# epoch:79  d_loss:0.6448  g_loss:2.2942
# epoch:80  d_loss:0.3914  g_loss:2.8387
# epoch:81  d_loss:0.3585  g_loss:3.1359
# epoch:82  d_loss:0.5449  g_loss:2.1641
# epoch:83  d_loss:0.5486  g_loss:2.0135
# epoch:84  d_loss:0.5059  g_loss:2.4264
# epoch:85  d_loss:0.4699  g_loss:2.7663
# epoch:86  d_loss:0.5298  g_loss:2.2053
# epoch:87  d_loss:0.3807  g_loss:2.1237
# epoch:88  d_loss:0.5120  g_loss:1.5082
# epoch:89  d_loss:0.5642  g_loss:1.4981
# epoch:90  d_loss:0.5040  g_loss:1.9864
# epoch:91  d_loss:0.3554  g_loss:2.1754
# epoch:92  d_loss:0.5544  g_loss:1.7494
# epoch:93  d_loss:0.3738  g_loss:1.7572
# epoch:94  d_loss:0.3675  g_loss:1.5207
# epoch:95  d_loss:0.4849  g_loss:1.9334
# epoch:96  d_loss:0.3052  g_loss:2.9614
# epoch:97  d_loss:0.3143  g_loss:3.2214
# epoch:98  d_loss:0.4623  g_loss:2.1493
# epoch:99  d_loss:0.3391  g_loss:2.1012
# epoch:100  d_loss:0.4162  g_loss:2.1249
# epoch:101  d_loss:0.3607  g_loss:2.6064
# epoch:102  d_loss:0.3935  g_loss:2.8084
# epoch:103  d_loss:0.3366  g_loss:2.9928
# epoch:104  d_loss:0.3537  g_loss:2.1744
# epoch:105  d_loss:0.5336  g_loss:1.8515
# epoch:106  d_loss:0.4562  g_loss:1.7686
# epoch:107  d_loss:0.3417  g_loss:2.4600
# epoch:108  d_loss:0.5076  g_loss:2.7413
# epoch:109  d_loss:0.6512  g_loss:1.9868
# epoch:110  d_loss:0.6267  g_loss:1.6383
# epoch:111  d_loss:0.4162  g_loss:1.6088
# epoch:112  d_loss:0.4468  g_loss:1.9790
# epoch:113  d_loss:0.5362  g_loss:2.2094
# epoch:114  d_loss:0.4323  g_loss:1.8344
# epoch:115  d_loss:0.5437  g_loss:1.5107
# epoch:116  d_loss:0.4350  g_loss:1.8061
# epoch:117  d_loss:0.5060  g_loss:1.8994
# epoch:118  d_loss:0.3722  g_loss:1.8259
# epoch:119  d_loss:0.4996  g_loss:1.7931
# epoch:120  d_loss:0.4850  g_loss:1.6874
# epoch:121  d_loss:0.3425  g_loss:2.0315
# epoch:122  d_loss:0.4690  g_loss:2.0086
# epoch:123  d_loss:0.5143  g_loss:1.6019
# epoch:124  d_loss:0.4818  g_loss:1.2915
# epoch:125  d_loss:0.5420  g_loss:1.5239
# epoch:126  d_loss:0.4000  g_loss:1.7089
# epoch:127  d_loss:0.3878  g_loss:2.2930
# epoch:128  d_loss:0.5236  g_loss:1.7268
# epoch:129  d_loss:0.6902  g_loss:1.5818
# epoch:130  d_loss:0.5121  g_loss:1.6081
# epoch:131  d_loss:0.5933  g_loss:1.6145
# epoch:132  d_loss:0.5197  g_loss:1.5554
# epoch:133  d_loss:0.4305  g_loss:1.5791
# epoch:134  d_loss:0.5649  g_loss:1.6052
# epoch:135  d_loss:0.4808  g_loss:1.5430
# epoch:136  d_loss:0.5498  g_loss:1.3800
# epoch:137  d_loss:0.4816  g_loss:1.7371
# epoch:138  d_loss:0.6024  g_loss:1.7451
# epoch:139  d_loss:0.5407  g_loss:1.4735
# epoch:140  d_loss:0.5045  g_loss:1.4020
# epoch:141  d_loss:0.6966  g_loss:1.2097
# epoch:142  d_loss:0.5410  g_loss:1.4733
# epoch:143  d_loss:0.4641  g_loss:1.8251
# epoch:144  d_loss:0.5344  g_loss:1.7499
# epoch:145  d_loss:0.5878  g_loss:1.6252
# epoch:146  d_loss:0.4212  g_loss:1.7696
# epoch:147  d_loss:0.4781  g_loss:1.3072
# epoch:148  d_loss:0.4374  g_loss:1.7200
# epoch:149  d_loss:0.5131  g_loss:1.7590
# epoch:150  d_loss:0.5483  g_loss:1.8083
# epoch:151  d_loss:0.5297  g_loss:1.6992
# epoch:152  d_loss:0.3881  g_loss:1.8302
# epoch:153  d_loss:0.4373  g_loss:1.8971
# epoch:154  d_loss:0.4602  g_loss:2.0037
# epoch:155  d_loss:0.5231  g_loss:1.7287
# epoch:156  d_loss:0.4676  g_loss:1.7338
# epoch:157  d_loss:0.4095  g_loss:1.8796
# epoch:158  d_loss:0.4321  g_loss:1.8541
# epoch:159  d_loss:0.4090  g_loss:1.8976
# epoch:160  d_loss:0.3462  g_loss:1.8220
# epoch:161  d_loss:0.3677  g_loss:1.9413
# epoch:162  d_loss:0.4596  g_loss:1.8776
# epoch:163  d_loss:0.5194  g_loss:1.6275
# epoch:164  d_loss:0.5534  g_loss:1.7310
# epoch:165  d_loss:0.4678  g_loss:1.6027
# epoch:166  d_loss:0.4335  g_loss:1.9776
# epoch:167  d_loss:0.2926  g_loss:2.1341
# epoch:168  d_loss:0.3787  g_loss:2.2312
# epoch:169  d_loss:0.6699  g_loss:1.7730
# epoch:170  d_loss:0.5409  g_loss:1.6364
# epoch:171  d_loss:0.5864  g_loss:1.7527
# epoch:172  d_loss:0.6634  g_loss:1.3397
# epoch:173  d_loss:0.5103  g_loss:1.4546
# epoch:174  d_loss:0.5482  g_loss:1.9760
# epoch:175  d_loss:0.6687  g_loss:1.8312
# epoch:176  d_loss:0.6466  g_loss:1.5156
# epoch:177  d_loss:0.6773  g_loss:1.4497
# epoch:178  d_loss:0.5510  g_loss:1.5346
# epoch:179  d_loss:0.5982  g_loss:1.7213
# epoch:180  d_loss:0.7481  g_loss:1.9100
# epoch:181  d_loss:0.6033  g_loss:1.7441
# epoch:182  d_loss:0.4393  g_loss:1.7613
# epoch:183  d_loss:0.4931  g_loss:1.5751
# epoch:184  d_loss:0.4469  g_loss:1.8698
# epoch:185  d_loss:0.4344  g_loss:1.9992
# epoch:186  d_loss:0.4646  g_loss:1.9717
# epoch:187  d_loss:0.3962  g_loss:2.1236
# epoch:188  d_loss:0.3130  g_loss:1.9585
# epoch:189  d_loss:0.4712  g_loss:1.7251
# epoch:190  d_loss:0.3881  g_loss:1.3878
# epoch:191  d_loss:0.4455  g_loss:1.2913
# epoch:192  d_loss:0.4899  g_loss:1.4436
# epoch:193  d_loss:0.2642  g_loss:2.2349
# epoch:194  d_loss:0.3458  g_loss:2.4829
# epoch:195  d_loss:0.4346  g_loss:2.4921
# epoch:196  d_loss:0.3946  g_loss:2.1235
# epoch:197  d_loss:0.3242  g_loss:2.0305
# epoch:198  d_loss:0.3538  g_loss:1.8677
# epoch:199  d_loss:0.4217  g_loss:1.8535
# epoch:200  d_loss:0.4620  g_loss:1.6355
# epoch:201  d_loss:0.6864  g_loss:1.6756
# epoch:202  d_loss:0.4995  g_loss:1.8331
# epoch:203  d_loss:0.3382  g_loss:2.1188
# epoch:204  d_loss:0.3704  g_loss:1.8779
# epoch:205  d_loss:0.5061  g_loss:1.8570
# epoch:206  d_loss:0.4050  g_loss:1.7847
# epoch:207  d_loss:0.4350  g_loss:1.9112
# epoch:208  d_loss:0.5123  g_loss:1.5253
# epoch:209  d_loss:0.4065  g_loss:1.5186
# epoch:210  d_loss:0.4035  g_loss:2.0682
# epoch:211  d_loss:0.3305  g_loss:2.0015
# epoch:212  d_loss:0.3626  g_loss:2.3716
# epoch:213  d_loss:0.3856  g_loss:1.8842
# epoch:214  d_loss:0.5753  g_loss:1.8401
# epoch:215  d_loss:0.4552  g_loss:1.6305
# epoch:216  d_loss:0.4375  g_loss:1.6874
# epoch:217  d_loss:0.2893  g_loss:2.5140
# epoch:218  d_loss:0.3386  g_loss:2.4470
# epoch:219  d_loss:0.5432  g_loss:2.4146
# epoch:220  d_loss:0.4169  g_loss:2.4647
# epoch:221  d_loss:0.3779  g_loss:1.9802
# epoch:222  d_loss:0.4793  g_loss:1.7880
# epoch:223  d_loss:0.4444  g_loss:2.2913
# epoch:224  d_loss:0.4322  g_loss:2.5483
# epoch:225  d_loss:0.4342  g_loss:3.2789
# epoch:226  d_loss:0.4813  g_loss:3.1993
# epoch:227  d_loss:0.5140  g_loss:2.6270
# epoch:228  d_loss:0.7232  g_loss:1.8524
# epoch:229  d_loss:0.6670  g_loss:1.7575
# epoch:230  d_loss:0.4951  g_loss:2.0746
# epoch:231  d_loss:0.5217  g_loss:2.4160
# epoch:232  d_loss:0.4160  g_loss:3.0234
# epoch:233  d_loss:0.3947  g_loss:3.2238
# epoch:234  d_loss:0.4507  g_loss:2.6280
# epoch:235  d_loss:0.4534  g_loss:2.0644
# epoch:236  d_loss:0.4701  g_loss:1.6734
# epoch:237  d_loss:0.4934  g_loss:2.1201
# epoch:238  d_loss:0.4864  g_loss:2.2874
# epoch:239  d_loss:0.5320  g_loss:2.3934
# epoch:240  d_loss:0.4588  g_loss:2.5344
# epoch:241  d_loss:0.6023  g_loss:2.0065
# epoch:242  d_loss:0.4312  g_loss:1.9754
# epoch:243  d_loss:0.8373  g_loss:1.6941
# epoch:244  d_loss:0.6104  g_loss:1.5144
# epoch:245  d_loss:0.5192  g_loss:1.6938
# epoch:246  d_loss:0.5581  g_loss:1.7065
# epoch:247  d_loss:0.6532  g_loss:1.8619
# epoch:248  d_loss:0.5748  g_loss:1.8389
# epoch:249  d_loss:0.5364  g_loss:2.0140
# epoch:250  d_loss:0.8462  g_loss:1.9761
# epoch:251  d_loss:0.7385  g_loss:1.9305
# epoch:252  d_loss:0.6628  g_loss:1.7392
# epoch:253  d_loss:0.6192  g_loss:1.8536
# epoch:254  d_loss:0.5744  g_loss:1.5195
# epoch:255  d_loss:0.6554  g_loss:1.4989
# epoch:256  d_loss:0.5369  g_loss:1.9475
# epoch:257  d_loss:0.6308  g_loss:1.9799
# epoch:258  d_loss:0.5158  g_loss:2.1720
# epoch:259  d_loss:0.3570  g_loss:2.2619
# epoch:260  d_loss:0.4224  g_loss:1.9860
# epoch:261  d_loss:0.4225  g_loss:2.6318
# epoch:262  d_loss:0.5267  g_loss:2.2107
# epoch:263  d_loss:0.3496  g_loss:2.5500
# epoch:264  d_loss:0.3146  g_loss:2.7367
# epoch:265  d_loss:0.2913  g_loss:2.8443
# epoch:266  d_loss:0.3216  g_loss:3.1166
# epoch:267  d_loss:0.3549  g_loss:3.1905
# epoch:268  d_loss:0.2926  g_loss:3.4636
# epoch:269  d_loss:0.3258  g_loss:2.5451
# epoch:270  d_loss:0.3433  g_loss:2.4230
# epoch:271  d_loss:0.3444  g_loss:1.8801
# epoch:272  d_loss:0.2848  g_loss:2.5554
# epoch:273  d_loss:0.3318  g_loss:2.5939
# epoch:274  d_loss:0.3693  g_loss:3.1411
# epoch:275  d_loss:0.4016  g_loss:3.0814
# epoch:276  d_loss:0.4812  g_loss:2.1781
# epoch:277  d_loss:0.4582  g_loss:1.9240
# epoch:278  d_loss:0.5073  g_loss:2.0563
# epoch:279  d_loss:0.4464  g_loss:2.0948
# epoch:280  d_loss:0.3066  g_loss:2.3917
# epoch:281  d_loss:0.3900  g_loss:2.1049
# epoch:282  d_loss:0.3154  g_loss:2.4585
# epoch:283  d_loss:0.2932  g_loss:2.3104
# epoch:284  d_loss:0.2689  g_loss:2.6757
# epoch:285  d_loss:0.2586  g_loss:2.4629
# epoch:286  d_loss:0.3045  g_loss:2.1387
# epoch:287  d_loss:0.2964  g_loss:2.8233
# epoch:288  d_loss:0.2681  g_loss:2.8839
# epoch:289  d_loss:0.2177  g_loss:2.9554
# epoch:290  d_loss:0.2329  g_loss:2.8591
# epoch:291  d_loss:0.2888  g_loss:2.7018
# epoch:292  d_loss:0.3057  g_loss:2.5523
# epoch:293  d_loss:0.2302  g_loss:2.4447
# epoch:294  d_loss:0.2426  g_loss:2.2530
# epoch:295  d_loss:0.2215  g_loss:2.7485
# epoch:296  d_loss:0.2461  g_loss:1.8324
# epoch:297  d_loss:0.5051  g_loss:2.4186
# epoch:298  d_loss:0.4282  g_loss:2.4881
# epoch:299  d_loss:0.3980  g_loss:2.7256
# epoch:300  d_loss:0.4813  g_loss:2.8100
# epoch:301  d_loss:0.3869  g_loss:3.1304
# epoch:302  d_loss:0.4137  g_loss:2.5379
# epoch:303  d_loss:0.5954  g_loss:1.6816
# epoch:304  d_loss:0.3522  g_loss:2.7640
# epoch:305  d_loss:0.2460  g_loss:3.1354
# epoch:306  d_loss:0.1350  g_loss:4.6304
# epoch:307  d_loss:0.6220  g_loss:3.5022
# epoch:308  d_loss:0.3435  g_loss:2.8007
# epoch:309  d_loss:0.2273  g_loss:2.1129
# epoch:310  d_loss:0.3714  g_loss:2.3227
# epoch:311  d_loss:0.1927  g_loss:3.0410
# epoch:312  d_loss:0.2898  g_loss:3.8007
# epoch:313  d_loss:0.1479  g_loss:4.1288
# epoch:314  d_loss:0.2071  g_loss:4.2041
# epoch:315  d_loss:0.1448  g_loss:4.0442
# epoch:316  d_loss:0.3962  g_loss:3.3266
# epoch:317  d_loss:0.6223  g_loss:1.9162
# epoch:318  d_loss:0.7013  g_loss:2.1219
# epoch:319  d_loss:0.4110  g_loss:3.0475
# epoch:320  d_loss:0.5768  g_loss:3.6963
# epoch:321  d_loss:0.5402  g_loss:4.1317
# epoch:322  d_loss:0.4900  g_loss:3.5884
# epoch:323  d_loss:0.5903  g_loss:2.5901
# epoch:324  d_loss:0.5754  g_loss:2.2886
# epoch:325  d_loss:0.4013  g_loss:2.2098
# epoch:326  d_loss:0.3996  g_loss:2.3022
# epoch:327  d_loss:0.4049  g_loss:2.1399
# epoch:328  d_loss:0.3377  g_loss:3.0496
# epoch:329  d_loss:0.3715  g_loss:2.5715
# epoch:330  d_loss:0.4930  g_loss:2.5061
# epoch:331  d_loss:0.4090  g_loss:2.4324
# epoch:332  d_loss:0.3430  g_loss:1.9344
# epoch:333  d_loss:0.3546  g_loss:2.0654
# epoch:334  d_loss:0.2432  g_loss:2.3962
# epoch:335  d_loss:0.4423  g_loss:2.9549
# epoch:336  d_loss:0.4671  g_loss:2.8077
# epoch:337  d_loss:0.5562  g_loss:2.8829
# epoch:338  d_loss:0.5576  g_loss:2.0929
# epoch:339  d_loss:0.3729  g_loss:2.6761
# epoch:340  d_loss:0.4380  g_loss:2.4490
# epoch:341  d_loss:0.3091  g_loss:2.3929
# epoch:342  d_loss:0.6445  g_loss:2.2279
# epoch:343  d_loss:0.3332  g_loss:2.5142
# epoch:344  d_loss:0.4399  g_loss:2.5541
# epoch:345  d_loss:0.4178  g_loss:2.5842
# epoch:346  d_loss:0.2484  g_loss:2.1890
# epoch:347  d_loss:0.4774  g_loss:2.0954
# epoch:348  d_loss:0.4143  g_loss:2.1641
# epoch:349  d_loss:0.4088  g_loss:2.8083
# epoch:350  d_loss:0.4146  g_loss:3.0584
# epoch:351  d_loss:0.3758  g_loss:2.6701
# epoch:352  d_loss:0.4682  g_loss:2.3684
# epoch:353  d_loss:0.3199  g_loss:2.4054
# epoch:354  d_loss:0.3542  g_loss:2.4055
# epoch:355  d_loss:0.2692  g_loss:3.1251
# epoch:356  d_loss:0.3970  g_loss:3.0281
# epoch:357  d_loss:0.3395  g_loss:3.0515
# epoch:358  d_loss:0.3470  g_loss:3.2213
# epoch:359  d_loss:0.4383  g_loss:2.4768
# epoch:360  d_loss:0.3946  g_loss:2.4474
# epoch:361  d_loss:0.1928  g_loss:2.7160
# epoch:362  d_loss:0.3316  g_loss:2.2641
# epoch:363  d_loss:0.3997  g_loss:2.2493
# epoch:364  d_loss:0.2509  g_loss:2.5721
# epoch:365  d_loss:0.2488  g_loss:3.0397
# epoch:366  d_loss:0.3140  g_loss:2.7728
# epoch:367  d_loss:0.3243  g_loss:3.3980
# epoch:368  d_loss:0.2381  g_loss:3.9125
# epoch:369  d_loss:0.3208  g_loss:3.3693
# epoch:370  d_loss:0.2537  g_loss:3.7968
# epoch:371  d_loss:0.2658  g_loss:3.1191
# epoch:372  d_loss:0.3929  g_loss:2.3132
# epoch:373  d_loss:0.6191  g_loss:1.8763
# epoch:374  d_loss:0.4061  g_loss:2.5038
# epoch:375  d_loss:0.4085  g_loss:2.8664
# epoch:376  d_loss:0.2851  g_loss:3.6899
# epoch:377  d_loss:0.3472  g_loss:3.2760
# epoch:378  d_loss:0.3590  g_loss:2.7808
# epoch:379  d_loss:0.4550  g_loss:2.1597
# epoch:380  d_loss:0.3633  g_loss:2.2976
# epoch:381  d_loss:0.3729  g_loss:2.2266
# epoch:382  d_loss:0.3733  g_loss:2.2748
# epoch:383  d_loss:0.4726  g_loss:2.2606
# epoch:384  d_loss:0.4470  g_loss:1.9609
# epoch:385  d_loss:0.3649  g_loss:2.3619
# epoch:386  d_loss:0.3821  g_loss:2.5937
# epoch:387  d_loss:0.4079  g_loss:2.3542
# epoch:388  d_loss:0.3079  g_loss:2.2045
# epoch:389  d_loss:0.3391  g_loss:1.6702
# epoch:390  d_loss:0.3665  g_loss:1.6763
# epoch:391  d_loss:0.2608  g_loss:2.5438
# epoch:392  d_loss:0.2920  g_loss:2.5472
# epoch:393  d_loss:0.2330  g_loss:3.0493
# epoch:394  d_loss:0.4423  g_loss:2.5160
# epoch:395  d_loss:0.3494  g_loss:2.5411
# epoch:396  d_loss:0.3387  g_loss:2.2454
# epoch:397  d_loss:0.2726  g_loss:2.4205
# epoch:398  d_loss:0.2953  g_loss:2.6805
# epoch:399  d_loss:0.3824  g_loss:2.8543
# epoch:400  d_loss:0.2711  g_loss:3.0430
# epoch:401  d_loss:0.2961  g_loss:2.7691
# epoch:402  d_loss:0.3863  g_loss:2.1171
# epoch:403  d_loss:0.2240  g_loss:1.9589
# epoch:404  d_loss:0.2968  g_loss:2.1921
# epoch:405  d_loss:0.1837  g_loss:2.8759
# epoch:406  d_loss:0.2946  g_loss:3.3600
# epoch:407  d_loss:0.3046  g_loss:3.3914
# epoch:408  d_loss:0.2457  g_loss:2.8483
# epoch:409  d_loss:0.2823  g_loss:2.4217
# epoch:410  d_loss:0.2469  g_loss:2.6362
# epoch:411  d_loss:0.2592  g_loss:2.5389
# epoch:412  d_loss:0.2744  g_loss:2.9369
# epoch:413  d_loss:0.2120  g_loss:3.1839
# epoch:414  d_loss:0.2311  g_loss:3.2380
# epoch:415  d_loss:0.2447  g_loss:3.0391
# epoch:416  d_loss:0.2352  g_loss:2.7523
# epoch:417  d_loss:0.2731  g_loss:2.8067
# epoch:418  d_loss:0.2313  g_loss:2.7970
# epoch:419  d_loss:0.2698  g_loss:2.5754
# epoch:420  d_loss:0.1613  g_loss:2.6728
# epoch:421  d_loss:0.3413  g_loss:2.3573
# epoch:422  d_loss:0.2821  g_loss:2.7096
# epoch:423  d_loss:0.2421  g_loss:2.7843
# epoch:424  d_loss:0.2443  g_loss:2.6428
# epoch:425  d_loss:0.3147  g_loss:2.1009
# epoch:426  d_loss:0.2283  g_loss:2.6833
# epoch:427  d_loss:0.4483  g_loss:2.7699
# epoch:428  d_loss:0.2940  g_loss:2.5883
# epoch:429  d_loss:0.2851  g_loss:2.6684
# epoch:430  d_loss:0.1763  g_loss:2.5732
# epoch:431  d_loss:0.3101  g_loss:2.6478
# epoch:432  d_loss:0.3088  g_loss:2.3614
# epoch:433  d_loss:0.3067  g_loss:2.8424
# epoch:434  d_loss:0.3188  g_loss:2.6378
# epoch:435  d_loss:0.1808  g_loss:2.8048
# epoch:436  d_loss:0.2917  g_loss:2.7942
# epoch:437  d_loss:0.2060  g_loss:2.8350
# epoch:438  d_loss:0.3083  g_loss:2.7465
# epoch:439  d_loss:0.2596  g_loss:3.1413
# epoch:440  d_loss:0.2726  g_loss:3.0393
# epoch:441  d_loss:0.2902  g_loss:3.2137
# epoch:442  d_loss:0.1762  g_loss:2.8325
# epoch:443  d_loss:0.2737  g_loss:2.9126
# epoch:444  d_loss:0.1749  g_loss:2.4439
# epoch:445  d_loss:0.1674  g_loss:2.7367
# epoch:446  d_loss:0.2548  g_loss:2.6662
# epoch:447  d_loss:0.2405  g_loss:2.9280
# epoch:448  d_loss:0.2444  g_loss:2.5644
# epoch:449  d_loss:0.2204  g_loss:2.7163
# epoch:450  d_loss:0.2282  g_loss:2.5342
# epoch:451  d_loss:0.3173  g_loss:2.0696
# epoch:452  d_loss:0.3824  g_loss:2.7430
# epoch:453  d_loss:0.3651  g_loss:2.3698
# epoch:454  d_loss:0.2641  g_loss:2.3975
# epoch:455  d_loss:0.3638  g_loss:2.9356
# epoch:456  d_loss:0.3248  g_loss:3.3273
# epoch:457  d_loss:0.3979  g_loss:2.5795
# epoch:458  d_loss:0.2362  g_loss:2.8123
# epoch:459  d_loss:0.3078  g_loss:2.5745
# epoch:460  d_loss:0.3149  g_loss:2.5498
# epoch:461  d_loss:0.3243  g_loss:3.0188
# epoch:462  d_loss:0.1806  g_loss:2.7654
# epoch:463  d_loss:0.3694  g_loss:2.6783
# epoch:464  d_loss:0.2563  g_loss:2.4106
# epoch:465  d_loss:0.2862  g_loss:2.1024
# epoch:466  d_loss:0.3068  g_loss:2.2112
# epoch:467  d_loss:0.2586  g_loss:2.6005
# epoch:468  d_loss:0.2359  g_loss:2.1482
# epoch:469  d_loss:0.2983  g_loss:2.4047
# epoch:470  d_loss:0.1773  g_loss:2.5556
# epoch:471  d_loss:0.2218  g_loss:2.5275
# epoch:472  d_loss:0.1925  g_loss:2.8200
# epoch:473  d_loss:0.2900  g_loss:2.8397
# epoch:474  d_loss:0.1983  g_loss:3.3679
# epoch:475  d_loss:0.2922  g_loss:3.2368
# epoch:476  d_loss:0.3575  g_loss:2.4901
# epoch:477  d_loss:0.2709  g_loss:1.9514
# epoch:478  d_loss:0.2465  g_loss:2.6596
# epoch:479  d_loss:0.1347  g_loss:3.0762
# epoch:480  d_loss:0.2778  g_loss:3.1253
# epoch:481  d_loss:0.2577  g_loss:2.3316
# epoch:482  d_loss:0.3552  g_loss:2.1041
# epoch:483  d_loss:0.4279  g_loss:1.8163
# epoch:484  d_loss:0.1992  g_loss:2.9419
# epoch:485  d_loss:0.2103  g_loss:3.2963
# epoch:486  d_loss:0.2486  g_loss:3.1006
# epoch:487  d_loss:0.1934  g_loss:3.5143
# epoch:488  d_loss:0.4334  g_loss:2.5802
# epoch:489  d_loss:0.3707  g_loss:2.1383
# epoch:490  d_loss:0.2195  g_loss:2.3175
# epoch:491  d_loss:0.2695  g_loss:2.6980
# epoch:492  d_loss:0.2121  g_loss:2.6529
# epoch:493  d_loss:0.2352  g_loss:3.0565
# epoch:494  d_loss:0.2311  g_loss:3.0214
# epoch:495  d_loss:0.1863  g_loss:2.3600
# epoch:496  d_loss:0.2046  g_loss:2.2303
# epoch:497  d_loss:0.1535  g_loss:2.9099
# epoch:498  d_loss:0.2022  g_loss:3.2575
# epoch:499  d_loss:0.1715  g_loss:3.1590
# epoch:500  d_loss:0.2955  g_loss:3.1003
# epoch:501  d_loss:0.3601  g_loss:2.6583
# epoch:502  d_loss:0.1834  g_loss:2.6458
# epoch:503  d_loss:0.1897  g_loss:2.5585
# epoch:504  d_loss:0.2624  g_loss:2.9714
# epoch:505  d_loss:0.2001  g_loss:3.0756
# epoch:506  d_loss:0.1294  g_loss:3.1230
# epoch:507  d_loss:0.2011  g_loss:2.7226
# epoch:508  d_loss:0.1738  g_loss:2.7085
# epoch:509  d_loss:0.1447  g_loss:2.9427
# epoch:510  d_loss:0.2799  g_loss:2.7593
# epoch:511  d_loss:0.1337  g_loss:3.2319
# epoch:512  d_loss:0.1548  g_loss:3.4991
# epoch:513  d_loss:0.2278  g_loss:2.4163
# epoch:514  d_loss:0.2549  g_loss:2.6446
# epoch:515  d_loss:0.1694  g_loss:2.8785
# epoch:516  d_loss:0.1654  g_loss:3.5777
# epoch:517  d_loss:0.2441  g_loss:3.9513
# epoch:518  d_loss:0.1493  g_loss:3.5211
# epoch:519  d_loss:0.2722  g_loss:2.6050
# epoch:520  d_loss:0.1891  g_loss:2.6779
# epoch:521  d_loss:0.1503  g_loss:2.8727
# epoch:522  d_loss:0.2738  g_loss:3.3143
# epoch:523  d_loss:0.1565  g_loss:3.6018
# epoch:524  d_loss:0.1661  g_loss:3.0928
# epoch:525  d_loss:0.2405  g_loss:2.7114
# epoch:526  d_loss:0.1993  g_loss:2.4678
# epoch:527  d_loss:0.2385  g_loss:2.6183
# epoch:528  d_loss:0.1818  g_loss:3.0463
# epoch:529  d_loss:0.1519  g_loss:2.9128
# epoch:530  d_loss:0.1838  g_loss:3.0676
# epoch:531  d_loss:0.2096  g_loss:3.2519
# epoch:532  d_loss:0.2126  g_loss:2.4104
# epoch:533  d_loss:0.2220  g_loss:2.6655
# epoch:534  d_loss:0.2099  g_loss:2.8336
# epoch:535  d_loss:0.2238  g_loss:3.3414
# epoch:536  d_loss:0.3308  g_loss:2.8229
# epoch:537  d_loss:0.1945  g_loss:2.5641
# epoch:538  d_loss:0.2062  g_loss:3.1673
# epoch:539  d_loss:0.1769  g_loss:2.6863
# epoch:540  d_loss:0.2210  g_loss:2.6983
# epoch:541  d_loss:0.1430  g_loss:2.8499
# epoch:542  d_loss:0.1934  g_loss:3.1627
# epoch:543  d_loss:0.2539  g_loss:2.5586
# epoch:544  d_loss:0.2167  g_loss:2.7369
# epoch:545  d_loss:0.1017  g_loss:3.4702
# epoch:546  d_loss:0.2395  g_loss:3.1240
# epoch:547  d_loss:0.2976  g_loss:1.5593
# epoch:548  d_loss:0.3210  g_loss:2.4865
# epoch:549  d_loss:0.1645  g_loss:3.6531
# epoch:550  d_loss:0.3965  g_loss:3.3848
# epoch:551  d_loss:0.2628  g_loss:2.3690
# epoch:552  d_loss:0.4251  g_loss:1.9888
# epoch:553  d_loss:0.3417  g_loss:2.3917
# epoch:554  d_loss:0.2268  g_loss:3.9686
# epoch:555  d_loss:0.2363  g_loss:3.7570
# epoch:556  d_loss:0.2873  g_loss:2.2138
# epoch:557  d_loss:0.1671  g_loss:2.0103
# epoch:558  d_loss:0.2968  g_loss:2.1682
# epoch:559  d_loss:0.1287  g_loss:3.8927
# epoch:560  d_loss:0.1229  g_loss:4.1610
# epoch:561  d_loss:0.2080  g_loss:3.0043
# epoch:562  d_loss:0.2159  g_loss:2.5794
# epoch:563  d_loss:0.2899  g_loss:2.1287
# epoch:564  d_loss:0.1775  g_loss:2.3277
# epoch:565  d_loss:0.1471  g_loss:2.8873
# epoch:566  d_loss:0.1883  g_loss:3.4223
# epoch:567  d_loss:0.1717  g_loss:3.9719
# epoch:568  d_loss:0.1787  g_loss:3.8050
# epoch:569  d_loss:0.1463  g_loss:3.0655
# epoch:570  d_loss:0.2566  g_loss:2.4311
# epoch:571  d_loss:0.1421  g_loss:2.7842
# epoch:572  d_loss:0.1327  g_loss:3.1387
# epoch:573  d_loss:0.1870  g_loss:3.7747
# epoch:574  d_loss:0.1771  g_loss:2.8373
# epoch:575  d_loss:0.1459  g_loss:3.1751
# epoch:576  d_loss:0.1960  g_loss:2.7904
# epoch:577  d_loss:0.1265  g_loss:2.9593
# epoch:578  d_loss:0.1046  g_loss:3.0873
# epoch:579  d_loss:0.1539  g_loss:3.3566
# epoch:580  d_loss:0.1767  g_loss:3.8467
# epoch:581  d_loss:0.1385  g_loss:3.4714
# epoch:582  d_loss:0.1156  g_loss:2.8290
# epoch:583  d_loss:0.2198  g_loss:3.2052
# epoch:584  d_loss:0.1336  g_loss:3.1434
# epoch:585  d_loss:0.1843  g_loss:2.6247
# epoch:586  d_loss:0.1324  g_loss:3.2779
# epoch:587  d_loss:0.2494  g_loss:3.1087
# epoch:588  d_loss:0.1454  g_loss:2.7512
# epoch:589  d_loss:0.1870  g_loss:2.6821
# epoch:590  d_loss:0.2463  g_loss:2.8468
# epoch:591  d_loss:0.2349  g_loss:2.4766
# epoch:592  d_loss:0.1407  g_loss:2.8513
# epoch:593  d_loss:0.1613  g_loss:3.6714
# epoch:594  d_loss:0.4188  g_loss:3.1787
# epoch:595  d_loss:0.1580  g_loss:2.4228
# epoch:596  d_loss:0.2444  g_loss:2.1473
# epoch:597  d_loss:0.2050  g_loss:2.8009
# epoch:598  d_loss:0.2492  g_loss:2.1511
# epoch:599  d_loss:0.2120  g_loss:2.6010
# epoch:600  d_loss:0.1989  g_loss:2.8624
# epoch:601  d_loss:0.3026  g_loss:2.7161
# epoch:602  d_loss:0.2148  g_loss:2.4684
# epoch:603  d_loss:0.2122  g_loss:2.7041
# epoch:604  d_loss:0.1818  g_loss:2.5908
# epoch:605  d_loss:0.4261  g_loss:2.9303
# epoch:606  d_loss:0.2348  g_loss:2.3248
# epoch:607  d_loss:0.3105  g_loss:1.8426
# epoch:608  d_loss:0.2667  g_loss:1.4639
# epoch:609  d_loss:0.4797  g_loss:2.7184
# epoch:610  d_loss:0.3582  g_loss:3.5765
# epoch:611  d_loss:0.3041  g_loss:2.5391
# epoch:612  d_loss:0.4106  g_loss:1.6733
# epoch:613  d_loss:0.4285  g_loss:1.4578
# epoch:614  d_loss:0.2806  g_loss:2.1324
# epoch:615  d_loss:0.3724  g_loss:2.0282
# epoch:616  d_loss:0.3784  g_loss:2.2009
# epoch:617  d_loss:0.2270  g_loss:1.7948
# epoch:618  d_loss:0.2889  g_loss:1.8620
# epoch:619  d_loss:0.4732  g_loss:1.6057
# epoch:620  d_loss:0.5831  g_loss:1.3258
# epoch:621  d_loss:0.3230  g_loss:1.6668
# epoch:622  d_loss:0.3275  g_loss:2.0313
# epoch:623  d_loss:0.4580  g_loss:2.4131
# epoch:624  d_loss:0.2913  g_loss:2.4368
# epoch:625  d_loss:0.3740  g_loss:1.6012
# epoch:626  d_loss:0.6010  g_loss:1.3742
# epoch:627  d_loss:0.5942  g_loss:1.2559
# epoch:628  d_loss:0.3254  g_loss:2.3758
# epoch:629  d_loss:0.4947  g_loss:2.6186
# epoch:630  d_loss:0.5353  g_loss:1.8181
# epoch:631  d_loss:0.4643  g_loss:1.4325
# epoch:632  d_loss:0.7238  g_loss:0.9463
# epoch:633  d_loss:0.8396  g_loss:1.0404
# epoch:634  d_loss:0.5327  g_loss:2.1230
# epoch:635  d_loss:0.7106  g_loss:1.6293
# epoch:636  d_loss:1.0600  g_loss:0.9312
# epoch:637  d_loss:1.0435  g_loss:0.8158
# epoch:638  d_loss:1.1579  g_loss:0.5718
# epoch:639  d_loss:0.5960  g_loss:0.7518
# epoch:640  d_loss:0.7265  g_loss:1.2778
# epoch:641  d_loss:0.7821  g_loss:1.1685
# epoch:642  d_loss:0.9353  g_loss:0.9595
# epoch:643  d_loss:0.8537  g_loss:0.8956
# epoch:644  d_loss:1.0293  g_loss:0.7854
# epoch:645  d_loss:0.7698  g_loss:0.8676
# epoch:646  d_loss:0.5447  g_loss:1.0287
# epoch:647  d_loss:0.8134  g_loss:1.5223
# epoch:648  d_loss:0.5495  g_loss:2.0128
# epoch:649  d_loss:0.5418  g_loss:1.7008
# epoch:650  d_loss:0.4567  g_loss:1.5604
# epoch:651  d_loss:0.3979  g_loss:1.3052
# epoch:652  d_loss:0.4824  g_loss:1.4459
# epoch:653  d_loss:0.4014  g_loss:1.5242
# epoch:654  d_loss:0.3379  g_loss:2.7074
# epoch:655  d_loss:0.3331  g_loss:3.0352
# epoch:656  d_loss:0.4049  g_loss:3.3797
# epoch:657  d_loss:0.2604  g_loss:3.0926
# epoch:658  d_loss:0.4062  g_loss:2.5149
# epoch:659  d_loss:0.8314  g_loss:1.2307
# epoch:660  d_loss:0.9845  g_loss:1.2123
# epoch:661  d_loss:0.5950  g_loss:3.4495
# epoch:662  d_loss:0.5361  g_loss:5.9898
# epoch:663  d_loss:0.6260  g_loss:3.8849
# epoch:664  d_loss:0.4515  g_loss:2.2721
# epoch:665  d_loss:1.0272  g_loss:1.3552
# epoch:666  d_loss:2.3552  g_loss:0.6605
# epoch:667  d_loss:1.4379  g_loss:0.9791
# epoch:668  d_loss:1.3535  g_loss:1.7605
# epoch:669  d_loss:0.5854  g_loss:4.0087
# epoch:670  d_loss:1.0958  g_loss:4.9808
# epoch:671  d_loss:0.8571  g_loss:5.0500
# epoch:672  d_loss:0.5171  g_loss:4.6814
# epoch:673  d_loss:0.5473  g_loss:3.3586
# epoch:674  d_loss:0.8978  g_loss:2.8686
# epoch:675  d_loss:0.6842  g_loss:1.9098
# epoch:676  d_loss:0.9499  g_loss:1.3261
# epoch:677  d_loss:1.0357  g_loss:1.1403
# epoch:678  d_loss:0.8511  g_loss:1.1422
# epoch:679  d_loss:0.9485  g_loss:1.5942
# epoch:680  d_loss:0.7355  g_loss:2.0482
# epoch:681  d_loss:0.5887  g_loss:2.0693
# epoch:682  d_loss:0.6031  g_loss:2.2270
# epoch:683  d_loss:0.5840  g_loss:2.1721
# epoch:684  d_loss:0.3363  g_loss:2.1921
# epoch:685  d_loss:0.3643  g_loss:2.2537
# epoch:686  d_loss:0.3192  g_loss:2.1545
# epoch:687  d_loss:0.3142  g_loss:2.2752
# epoch:688  d_loss:0.2563  g_loss:2.6885
# epoch:689  d_loss:0.2451  g_loss:2.8608
# epoch:690  d_loss:0.1800  g_loss:3.6341
# epoch:691  d_loss:0.2827  g_loss:3.6391
# epoch:692  d_loss:0.2357  g_loss:3.5973
# epoch:693  d_loss:0.3021  g_loss:3.0805
# epoch:694  d_loss:0.1784  g_loss:2.9916
# epoch:695  d_loss:0.2988  g_loss:2.8731
# epoch:696  d_loss:0.2871  g_loss:2.7659
# epoch:697  d_loss:0.2924  g_loss:2.6994
# epoch:698  d_loss:0.3126  g_loss:2.7569
# epoch:699  d_loss:0.1666  g_loss:2.8149
# epoch:700  d_loss:0.2318  g_loss:2.7664
# epoch:701  d_loss:0.2058  g_loss:2.8213
# epoch:702  d_loss:0.3319  g_loss:2.7161
# epoch:703  d_loss:0.3721  g_loss:2.7681
# epoch:704  d_loss:0.2285  g_loss:2.6883
# epoch:705  d_loss:0.4300  g_loss:2.5286
# epoch:706  d_loss:0.4705  g_loss:2.1340
# epoch:707  d_loss:0.5076  g_loss:1.6694
# epoch:708  d_loss:0.6271  g_loss:1.3788
# epoch:709  d_loss:0.5076  g_loss:1.6556
# epoch:710  d_loss:0.6284  g_loss:1.4725
# epoch:711  d_loss:0.6297  g_loss:1.3846
# epoch:712  d_loss:0.5195  g_loss:1.4568
# epoch:713  d_loss:0.4437  g_loss:2.1158
# epoch:714  d_loss:0.3494  g_loss:2.2327
# epoch:715  d_loss:0.4514  g_loss:2.0600
# epoch:716  d_loss:0.4235  g_loss:1.9839
# epoch:717  d_loss:0.4024  g_loss:2.6068
# epoch:718  d_loss:0.3328  g_loss:2.5609
# epoch:719  d_loss:0.5145  g_loss:2.5596
# epoch:720  d_loss:0.4384  g_loss:2.2351
# epoch:721  d_loss:0.2770  g_loss:2.2376
# epoch:722  d_loss:0.2532  g_loss:1.9258
# epoch:723  d_loss:0.3334  g_loss:2.1318
# epoch:724  d_loss:0.1677  g_loss:2.3969
# epoch:725  d_loss:0.2179  g_loss:2.4091
# epoch:726  d_loss:0.2252  g_loss:2.4187
# epoch:727  d_loss:0.2938  g_loss:2.4053
# epoch:728  d_loss:0.3205  g_loss:2.0518
# epoch:729  d_loss:0.2237  g_loss:3.0437
# epoch:730  d_loss:0.2432  g_loss:2.1297
# epoch:731  d_loss:0.2242  g_loss:2.5011
# epoch:732  d_loss:0.4361  g_loss:2.4142
# epoch:733  d_loss:0.3816  g_loss:2.8399
# epoch:734  d_loss:0.3836  g_loss:2.2947
# epoch:735  d_loss:0.5295  g_loss:1.9915
# epoch:736  d_loss:0.5505  g_loss:2.1984
# epoch:737  d_loss:0.5433  g_loss:1.6416
# epoch:738  d_loss:0.5315  g_loss:1.6715
# epoch:739  d_loss:0.5356  g_loss:2.1905
# epoch:740  d_loss:0.6168  g_loss:1.6669
# epoch:741  d_loss:0.6963  g_loss:1.3783
# epoch:742  d_loss:0.7875  g_loss:1.3264
# epoch:743  d_loss:0.5807  g_loss:1.0130
# epoch:744  d_loss:0.8012  g_loss:1.2390
# epoch:745  d_loss:0.5008  g_loss:1.5459
# epoch:746  d_loss:0.4993  g_loss:1.6721
# epoch:747  d_loss:0.4015  g_loss:2.0916
# epoch:748  d_loss:0.5689  g_loss:1.8131
# epoch:749  d_loss:0.3561  g_loss:1.8207
# epoch:750  d_loss:0.3536  g_loss:1.6985
# epoch:751  d_loss:0.2754  g_loss:2.2933
# epoch:752  d_loss:0.3703  g_loss:2.0481
# epoch:753  d_loss:0.2203  g_loss:2.9450
# epoch:754  d_loss:0.2818  g_loss:2.5964
# epoch:755  d_loss:0.1510  g_loss:2.7002
# epoch:756  d_loss:0.2107  g_loss:2.8692
# epoch:757  d_loss:0.1592  g_loss:2.7121
# epoch:758  d_loss:0.2834  g_loss:2.4941
# epoch:759  d_loss:0.3428  g_loss:1.9819
# epoch:760  d_loss:0.2807  g_loss:2.1243
# epoch:761  d_loss:0.2915  g_loss:2.4144
# epoch:762  d_loss:0.3698  g_loss:1.9390
# epoch:763  d_loss:0.3380  g_loss:1.7874
# epoch:764  d_loss:0.3229  g_loss:2.0919
# epoch:765  d_loss:0.4912  g_loss:1.7556
# epoch:766  d_loss:0.4796  g_loss:1.2963
# epoch:767  d_loss:0.4095  g_loss:1.7055
# epoch:768  d_loss:0.3911  g_loss:1.6220
# epoch:769  d_loss:0.7119  g_loss:1.2213
# epoch:770  d_loss:0.6450  g_loss:1.3603
# epoch:771  d_loss:0.6935  g_loss:1.2859
# epoch:772  d_loss:0.7872  g_loss:1.5087
# epoch:773  d_loss:0.7033  g_loss:1.1998
# epoch:774  d_loss:0.7847  g_loss:1.5225
# epoch:775  d_loss:0.5560  g_loss:1.7110
# epoch:776  d_loss:0.5338  g_loss:1.4279
# epoch:777  d_loss:0.5145  g_loss:1.4223
# epoch:778  d_loss:0.5355  g_loss:1.6521
# epoch:779  d_loss:0.4142  g_loss:1.8435
# epoch:780  d_loss:0.4212  g_loss:1.8650
# epoch:781  d_loss:0.3003  g_loss:2.1225
# epoch:782  d_loss:0.2396  g_loss:2.2788
# epoch:783  d_loss:0.1909  g_loss:2.3256
# epoch:784  d_loss:0.2106  g_loss:2.2229
# epoch:785  d_loss:0.2317  g_loss:2.2997
# epoch:786  d_loss:0.2075  g_loss:2.3456
# epoch:787  d_loss:0.2089  g_loss:2.5428
# epoch:788  d_loss:0.1621  g_loss:2.7929
# epoch:789  d_loss:0.2197  g_loss:2.9473
# epoch:790  d_loss:0.2267  g_loss:2.4887
# epoch:791  d_loss:0.3897  g_loss:2.1230
# epoch:792  d_loss:0.3419  g_loss:1.4862
# epoch:793  d_loss:0.4466  g_loss:1.4440
# epoch:794  d_loss:0.3912  g_loss:1.5739
# epoch:795  d_loss:0.4268  g_loss:2.4461
# epoch:796  d_loss:0.5719  g_loss:2.2900
# epoch:797  d_loss:0.5317  g_loss:1.9903
# epoch:798  d_loss:0.5319  g_loss:1.8832
# epoch:799  d_loss:0.6075  g_loss:1.5333
# epoch:800  d_loss:0.6014  g_loss:1.3716
# epoch:801  d_loss:0.5870  g_loss:1.2989
# epoch:802  d_loss:0.4969  g_loss:1.7876
# epoch:803  d_loss:0.4392  g_loss:2.7023
# epoch:804  d_loss:0.4577  g_loss:2.3661
# epoch:805  d_loss:0.4828  g_loss:2.0892
# epoch:806  d_loss:0.7139  g_loss:1.7242
# epoch:807  d_loss:0.6239  g_loss:1.7537
# epoch:808  d_loss:0.4740  g_loss:1.6052
# epoch:809  d_loss:0.5713  g_loss:1.5090
# epoch:810  d_loss:0.5999  g_loss:1.7794
# epoch:811  d_loss:0.4381  g_loss:1.7980
# epoch:812  d_loss:0.4963  g_loss:2.0132
# epoch:813  d_loss:0.4231  g_loss:1.9669
# epoch:814  d_loss:0.3733  g_loss:2.2409
# epoch:815  d_loss:0.3536  g_loss:2.1368
# epoch:816  d_loss:0.4130  g_loss:1.8410
# epoch:817  d_loss:0.2549  g_loss:1.7882
# epoch:818  d_loss:0.3272  g_loss:2.3203
# epoch:819  d_loss:0.4423  g_loss:2.0020
# epoch:820  d_loss:0.2453  g_loss:2.3440
# epoch:821  d_loss:0.2000  g_loss:2.2459
# epoch:822  d_loss:0.2764  g_loss:2.0390
# epoch:823  d_loss:0.2355  g_loss:2.1222
# epoch:824  d_loss:0.3977  g_loss:2.3217
# epoch:825  d_loss:0.3610  g_loss:2.0511
# epoch:826  d_loss:0.4152  g_loss:1.6172
# epoch:827  d_loss:0.3825  g_loss:1.7569
# epoch:828  d_loss:0.5293  g_loss:1.5650
# epoch:829  d_loss:0.4906  g_loss:1.6266
# epoch:830  d_loss:0.5688  g_loss:1.3950
# epoch:831  d_loss:0.7557  g_loss:1.5363
# epoch:832  d_loss:0.8101  g_loss:1.8450
# epoch:833  d_loss:0.6801  g_loss:1.6735
# epoch:834  d_loss:0.5930  g_loss:1.6124
# epoch:835  d_loss:0.4259  g_loss:1.7407
# epoch:836  d_loss:0.3192  g_loss:2.2072
# epoch:837  d_loss:0.2945  g_loss:2.5344
# epoch:838  d_loss:0.3165  g_loss:2.7834
# epoch:839  d_loss:0.1622  g_loss:2.9798
# epoch:840  d_loss:0.1393  g_loss:3.1355
# epoch:841  d_loss:0.1840  g_loss:3.1060
# epoch:842  d_loss:0.4212  g_loss:3.1513
# epoch:843  d_loss:0.4013  g_loss:2.5060
# epoch:844  d_loss:0.8295  g_loss:2.7955
# epoch:845  d_loss:0.4752  g_loss:2.4566
# epoch:846  d_loss:1.2363  g_loss:2.1976
# epoch:847  d_loss:1.0796  g_loss:2.6598
# epoch:848  d_loss:0.5268  g_loss:3.2307
# epoch:849  d_loss:0.4606  g_loss:3.6315
# epoch:850  d_loss:0.3666  g_loss:3.9188
# epoch:851  d_loss:0.4101  g_loss:4.4200
# epoch:852  d_loss:0.2302  g_loss:4.6337
# epoch:853  d_loss:0.1440  g_loss:5.0642
# epoch:854  d_loss:0.1464  g_loss:4.6901
# epoch:855  d_loss:0.3321  g_loss:4.7219
# epoch:856  d_loss:0.4462  g_loss:5.7225
# epoch:857  d_loss:0.1394  g_loss:5.5162
# epoch:858  d_loss:0.2809  g_loss:5.0488
# epoch:859  d_loss:0.3579  g_loss:4.7655
# epoch:860  d_loss:0.2273  g_loss:4.0463
# epoch:861  d_loss:0.4232  g_loss:2.6714
# epoch:862  d_loss:0.3938  g_loss:2.3885
# epoch:863  d_loss:0.2595  g_loss:2.2362
# epoch:864  d_loss:0.3176  g_loss:2.2032
# epoch:865  d_loss:0.4044  g_loss:1.9275
# epoch:866  d_loss:0.2918  g_loss:2.3155
# epoch:867  d_loss:0.3248  g_loss:2.2342
# epoch:868  d_loss:0.5060  g_loss:2.0524
# epoch:869  d_loss:0.5611  g_loss:1.5578
# epoch:870  d_loss:0.5927  g_loss:1.3426
# epoch:871  d_loss:0.5094  g_loss:1.5664
# epoch:872  d_loss:0.4590  g_loss:2.2736
# epoch:873  d_loss:0.2837  g_loss:2.3076
# epoch:874  d_loss:0.4646  g_loss:2.8849
# epoch:875  d_loss:0.3811  g_loss:2.7488
# epoch:876  d_loss:0.2908  g_loss:2.5507
# epoch:877  d_loss:0.2128  g_loss:2.5709
# epoch:878  d_loss:0.1765  g_loss:2.9515
# epoch:879  d_loss:0.2142  g_loss:2.9881
# epoch:880  d_loss:0.2601  g_loss:3.8125
# epoch:881  d_loss:0.2098  g_loss:3.5460
# epoch:882  d_loss:0.2830  g_loss:3.6310
# epoch:883  d_loss:0.3875  g_loss:3.2207
# epoch:884  d_loss:0.3710  g_loss:2.9703
# epoch:885  d_loss:0.4776  g_loss:2.7942
# epoch:886  d_loss:0.4139  g_loss:2.3824
# epoch:887  d_loss:0.3985  g_loss:2.5161
# epoch:888  d_loss:0.5073  g_loss:2.6697
# epoch:889  d_loss:0.4742  g_loss:1.9215
# epoch:890  d_loss:0.4707  g_loss:1.7023
# epoch:891  d_loss:0.4346  g_loss:2.3799
# epoch:892  d_loss:0.4970  g_loss:2.2361
# epoch:893  d_loss:0.4700  g_loss:1.8105
# epoch:894  d_loss:0.4842  g_loss:1.7746
# epoch:895  d_loss:0.3862  g_loss:1.9465
# epoch:896  d_loss:0.2662  g_loss:2.5552
# epoch:897  d_loss:0.3078  g_loss:2.4163
# epoch:898  d_loss:0.2973  g_loss:2.3712
# epoch:899  d_loss:0.2489  g_loss:2.2671
# epoch:900  d_loss:0.3015  g_loss:2.7443
# epoch:901  d_loss:0.1823  g_loss:2.1132
# epoch:902  d_loss:0.2729  g_loss:2.1388
# epoch:903  d_loss:0.2119  g_loss:2.0694
# epoch:904  d_loss:0.2046  g_loss:2.1726
# epoch:905  d_loss:0.2612  g_loss:2.6642
# epoch:906  d_loss:0.2248  g_loss:2.6034
# epoch:907  d_loss:0.2985  g_loss:3.0443
# epoch:908  d_loss:0.3203  g_loss:2.6956
# epoch:909  d_loss:0.2534  g_loss:2.4637
# epoch:910  d_loss:0.2047  g_loss:2.3376
# epoch:911  d_loss:0.3036  g_loss:1.8763
# epoch:912  d_loss:0.2543  g_loss:1.9025
# epoch:913  d_loss:0.3046  g_loss:1.4826
# epoch:914  d_loss:0.3296  g_loss:2.0344
# epoch:915  d_loss:0.2567  g_loss:2.7153
# epoch:916  d_loss:0.4431  g_loss:2.0469
# epoch:917  d_loss:0.2783  g_loss:2.4110
# epoch:918  d_loss:0.3403  g_loss:1.8560
# epoch:919  d_loss:0.2662  g_loss:2.2262
# epoch:920  d_loss:0.2801  g_loss:2.2126
# epoch:921  d_loss:0.4398  g_loss:2.5873
# epoch:922  d_loss:0.4352  g_loss:2.1756
# epoch:923  d_loss:0.4345  g_loss:1.8183
# epoch:924  d_loss:0.3537  g_loss:1.8473
# epoch:925  d_loss:0.4369  g_loss:1.5950
# epoch:926  d_loss:0.2477  g_loss:2.0925
# epoch:927  d_loss:0.4466  g_loss:2.2382
# epoch:928  d_loss:0.2865  g_loss:2.6825
# epoch:929  d_loss:0.3881  g_loss:2.1685
# epoch:930  d_loss:0.4093  g_loss:2.0457
# epoch:931  d_loss:0.3440  g_loss:1.8397
# epoch:932  d_loss:0.3205  g_loss:1.9701
# epoch:933  d_loss:0.4033  g_loss:1.9686
# epoch:934  d_loss:0.4400  g_loss:1.5677
# epoch:935  d_loss:0.2935  g_loss:2.0432
# epoch:936  d_loss:0.2880  g_loss:2.2060
# epoch:937  d_loss:0.3272  g_loss:1.9112
# epoch:938  d_loss:0.2929  g_loss:2.3337
# epoch:939  d_loss:0.2859  g_loss:2.2315
# epoch:940  d_loss:0.2127  g_loss:2.2404
# epoch:941  d_loss:0.3175  g_loss:2.0281
# epoch:942  d_loss:0.2764  g_loss:2.1192
# epoch:943  d_loss:0.3484  g_loss:1.9123
# epoch:944  d_loss:0.2363  g_loss:2.4371
# epoch:945  d_loss:0.5942  g_loss:2.3469
# epoch:946  d_loss:0.3475  g_loss:2.0268
# epoch:947  d_loss:0.3519  g_loss:2.3223
# epoch:948  d_loss:0.4049  g_loss:2.0883
# epoch:949  d_loss:0.3850  g_loss:1.9083
# epoch:950  d_loss:0.3591  g_loss:1.4900
# epoch:951  d_loss:0.3101  g_loss:1.7507
# epoch:952  d_loss:0.3732  g_loss:1.5040
# epoch:953  d_loss:0.4194  g_loss:1.7722
# epoch:954  d_loss:0.4157  g_loss:1.5508
# epoch:955  d_loss:0.3747  g_loss:1.5437
# epoch:956  d_loss:0.4489  g_loss:1.9121
# epoch:957  d_loss:0.5285  g_loss:1.4476
# epoch:958  d_loss:0.3131  g_loss:1.6831
# epoch:959  d_loss:0.4668  g_loss:1.8447
# epoch:960  d_loss:0.3616  g_loss:1.8481
# epoch:961  d_loss:0.4505  g_loss:1.4530
# epoch:962  d_loss:0.3435  g_loss:2.0844
# epoch:963  d_loss:0.4005  g_loss:1.8320
# epoch:964  d_loss:0.3492  g_loss:2.1271
# epoch:965  d_loss:0.4549  g_loss:1.9234
# epoch:966  d_loss:0.3531  g_loss:2.0857
# epoch:967  d_loss:0.5154  g_loss:1.7527
# epoch:968  d_loss:0.3058  g_loss:2.0503
# epoch:969  d_loss:0.4831  g_loss:1.8823
# epoch:970  d_loss:0.4330  g_loss:1.4993
# epoch:971  d_loss:0.4175  g_loss:1.9048
# epoch:972  d_loss:0.3866  g_loss:1.9338
# epoch:973  d_loss:0.3710  g_loss:1.6863
# epoch:974  d_loss:0.4585  g_loss:1.8070
# epoch:975  d_loss:0.3427  g_loss:1.7232
# epoch:976  d_loss:0.4211  g_loss:1.7573
# epoch:977  d_loss:0.3573  g_loss:1.9536
# epoch:978  d_loss:0.3424  g_loss:2.1422
# epoch:979  d_loss:0.4496  g_loss:1.9605
# epoch:980  d_loss:0.5163  g_loss:1.2835
# epoch:981  d_loss:0.4267  g_loss:1.3786
# epoch:982  d_loss:0.2819  g_loss:1.5736
# epoch:983  d_loss:0.4017  g_loss:1.9166
# epoch:984  d_loss:0.4028  g_loss:2.0712
# epoch:985  d_loss:0.3373  g_loss:2.4947
# epoch:986  d_loss:0.4227  g_loss:2.1527
# epoch:987  d_loss:0.3474  g_loss:1.8215
# epoch:988  d_loss:0.3529  g_loss:1.5108
# epoch:989  d_loss:0.3596  g_loss:1.7772
# epoch:990  d_loss:0.2906  g_loss:1.9609
# epoch:991  d_loss:0.3363  g_loss:1.7649
# epoch:992  d_loss:0.2465  g_loss:2.2422
# epoch:993  d_loss:0.4760  g_loss:2.3169
# epoch:994  d_loss:0.4968  g_loss:1.9822
# epoch:995  d_loss:0.4650  g_loss:1.5097
# epoch:996  d_loss:0.3588  g_loss:1.4610
# epoch:997  d_loss:0.4728  g_loss:1.2189
# epoch:998  d_loss:0.4265  g_loss:1.4159
# epoch:999  d_loss:0.3248  g_loss:1.5342
# epoch:1000  d_loss:0.4852  g_loss:1.7954
# epoch:1001  d_loss:0.4858  g_loss:1.8618
# epoch:1002  d_loss:0.4153  g_loss:1.3893
# epoch:1003  d_loss:0.5916  g_loss:1.3537
# epoch:1004  d_loss:0.3081  g_loss:1.6120
# epoch:1005  d_loss:0.4126  g_loss:1.3773
# epoch:1006  d_loss:0.4938  g_loss:1.6306
# epoch:1007  d_loss:0.4943  g_loss:1.6651
# epoch:1008  d_loss:0.4566  g_loss:1.4288
# epoch:1009  d_loss:0.4656  g_loss:1.9129
# epoch:1010  d_loss:0.4539  g_loss:1.6602
# epoch:1011  d_loss:0.3909  g_loss:1.6712
# epoch:1012  d_loss:0.3387  g_loss:1.6582
# epoch:1013  d_loss:0.3730  g_loss:1.9025
# epoch:1014  d_loss:0.3990  g_loss:2.1480
# epoch:1015  d_loss:0.3408  g_loss:2.0579
# epoch:1016  d_loss:0.3196  g_loss:1.8584
# epoch:1017  d_loss:0.3604  g_loss:1.7065
# epoch:1018  d_loss:0.4695  g_loss:1.8443
# epoch:1019  d_loss:0.4584  g_loss:1.8180
# epoch:1020  d_loss:0.2054  g_loss:2.2886
# epoch:1021  d_loss:0.6454  g_loss:1.9905
# epoch:1022  d_loss:0.3797  g_loss:2.3886
# epoch:1023  d_loss:0.3611  g_loss:2.1230
# epoch:1024  d_loss:0.2786  g_loss:2.0718
# epoch:1025  d_loss:0.2822  g_loss:1.8857
# epoch:1026  d_loss:0.3675  g_loss:1.7227
# epoch:1027  d_loss:0.3752  g_loss:1.9824
# epoch:1028  d_loss:0.5410  g_loss:1.7530
# epoch:1029  d_loss:0.2574  g_loss:2.4396
# epoch:1030  d_loss:0.4806  g_loss:2.3110
# epoch:1031  d_loss:0.3163  g_loss:2.6030
# epoch:1032  d_loss:0.5089  g_loss:2.0735
# epoch:1033  d_loss:0.3824  g_loss:2.3588
# epoch:1034  d_loss:0.2718  g_loss:2.4605
# epoch:1035  d_loss:0.4458  g_loss:2.2426
# epoch:1036  d_loss:0.3076  g_loss:2.4354
# epoch:1037  d_loss:0.2377  g_loss:3.2112
# epoch:1038  d_loss:0.2920  g_loss:2.8162
# epoch:1039  d_loss:0.2634  g_loss:2.8653
# epoch:1040  d_loss:0.3446  g_loss:2.8395
# epoch:1041  d_loss:0.3811  g_loss:2.5614
# epoch:1042  d_loss:0.2341  g_loss:2.3754
# epoch:1043  d_loss:0.2491  g_loss:2.1212
# epoch:1044  d_loss:0.3161  g_loss:2.0052
# epoch:1045  d_loss:0.2380  g_loss:2.3284
# epoch:1046  d_loss:0.3150  g_loss:2.5796
# epoch:1047  d_loss:0.1748  g_loss:3.0141
# epoch:1048  d_loss:0.3171  g_loss:2.4095
# epoch:1049  d_loss:0.4821  g_loss:2.1894
# epoch:1050  d_loss:0.3173  g_loss:1.9517
# epoch:1051  d_loss:0.2952  g_loss:1.7146
# epoch:1052  d_loss:0.3864  g_loss:2.3289
# epoch:1053  d_loss:0.3587  g_loss:2.3828
# epoch:1054  d_loss:0.3198  g_loss:3.1661
# epoch:1055  d_loss:0.3457  g_loss:2.4684
# epoch:1056  d_loss:0.4669  g_loss:2.1972
# epoch:1057  d_loss:0.2496  g_loss:2.4088
# epoch:1058  d_loss:0.2200  g_loss:2.2540
# epoch:1059  d_loss:0.3362  g_loss:2.4621
# epoch:1060  d_loss:0.1768  g_loss:2.5417
# epoch:1061  d_loss:0.1495  g_loss:2.9428
# epoch:1062  d_loss:0.2381  g_loss:2.6059
# epoch:1063  d_loss:0.2525  g_loss:2.9366
# epoch:1064  d_loss:0.2032  g_loss:2.7678
# epoch:1065  d_loss:0.1680  g_loss:3.0473
# epoch:1066  d_loss:0.2196  g_loss:2.7368
# epoch:1067  d_loss:0.1797  g_loss:3.0216
# epoch:1068  d_loss:0.2614  g_loss:3.0849
# epoch:1069  d_loss:0.1746  g_loss:2.7368
# epoch:1070  d_loss:0.3118  g_loss:2.2712
# epoch:1071  d_loss:0.2597  g_loss:2.3075
# epoch:1072  d_loss:0.2236  g_loss:2.9889
# epoch:1073  d_loss:0.2103  g_loss:3.0823
# epoch:1074  d_loss:0.2064  g_loss:3.2407
# epoch:1075  d_loss:0.2786  g_loss:2.8221
# epoch:1076  d_loss:0.2776  g_loss:2.7168
# epoch:1077  d_loss:0.2858  g_loss:2.2445
# epoch:1078  d_loss:0.2489  g_loss:2.4990
# epoch:1079  d_loss:0.2779  g_loss:3.1671
# epoch:1080  d_loss:0.2222  g_loss:3.2378
# epoch:1081  d_loss:0.4161  g_loss:2.7794
# epoch:1082  d_loss:0.3237  g_loss:2.5500
# epoch:1083  d_loss:0.3560  g_loss:2.4881
# epoch:1084  d_loss:0.3821  g_loss:1.9355
# epoch:1085  d_loss:0.5610  g_loss:2.2172
# epoch:1086  d_loss:0.4036  g_loss:2.3431
# epoch:1087  d_loss:0.3555  g_loss:2.6994
# epoch:1088  d_loss:0.3267  g_loss:2.5934
# epoch:1089  d_loss:0.5245  g_loss:2.1571
# epoch:1090  d_loss:0.3482  g_loss:1.8839
# epoch:1091  d_loss:0.5101  g_loss:2.1969
# epoch:1092  d_loss:0.3842  g_loss:2.0531
# epoch:1093  d_loss:0.3805  g_loss:2.1088
# epoch:1094  d_loss:0.4326  g_loss:2.1859
# epoch:1095  d_loss:0.3863  g_loss:2.1680
# epoch:1096  d_loss:0.2500  g_loss:2.1338
# epoch:1097  d_loss:0.3351  g_loss:2.2134
# epoch:1098  d_loss:0.2983  g_loss:2.2098
# epoch:1099  d_loss:0.3965  g_loss:1.8515
# epoch:1100  d_loss:0.3368  g_loss:1.8874
# epoch:1101  d_loss:0.4590  g_loss:2.0161
# epoch:1102  d_loss:0.2769  g_loss:2.1157
# epoch:1103  d_loss:0.3507  g_loss:2.3296
# epoch:1104  d_loss:0.2701  g_loss:2.6214
# epoch:1105  d_loss:0.3992  g_loss:1.8819
# epoch:1106  d_loss:0.3064  g_loss:2.1835
# epoch:1107  d_loss:0.4227  g_loss:2.6391
# epoch:1108  d_loss:0.2846  g_loss:2.3490
# epoch:1109  d_loss:0.3332  g_loss:2.4532
# epoch:1110  d_loss:0.4395  g_loss:2.2342
# epoch:1111  d_loss:0.3813  g_loss:2.4648
# epoch:1112  d_loss:0.2885  g_loss:2.5484
# epoch:1113  d_loss:0.3471  g_loss:2.1293
# epoch:1114  d_loss:0.3056  g_loss:2.2502
# epoch:1115  d_loss:0.3581  g_loss:2.7720
# epoch:1116  d_loss:0.1833  g_loss:3.4138
# epoch:1117  d_loss:0.4019  g_loss:3.2905
# epoch:1118  d_loss:0.3585  g_loss:2.0934
# epoch:1119  d_loss:0.5540  g_loss:1.9555
# epoch:1120  d_loss:0.3548  g_loss:2.1311
# epoch:1121  d_loss:0.4019  g_loss:2.3528
# epoch:1122  d_loss:0.2690  g_loss:2.6762
# epoch:1123  d_loss:0.2483  g_loss:3.0322
# epoch:1124  d_loss:0.4133  g_loss:2.3576
# epoch:1125  d_loss:0.2764  g_loss:2.5559
# epoch:1126  d_loss:0.3504  g_loss:2.4385
# epoch:1127  d_loss:0.2737  g_loss:2.5446
# epoch:1128  d_loss:0.4033  g_loss:2.3075
# epoch:1129  d_loss:0.2483  g_loss:2.6477
# epoch:1130  d_loss:0.4133  g_loss:2.1467
# epoch:1131  d_loss:0.2395  g_loss:2.6890
# epoch:1132  d_loss:0.2769  g_loss:3.1669
# epoch:1133  d_loss:0.2926  g_loss:2.9397
# epoch:1134  d_loss:0.3202  g_loss:2.8316
# epoch:1135  d_loss:0.4630  g_loss:2.3379
# epoch:1136  d_loss:0.2269  g_loss:3.1103
# epoch:1137  d_loss:0.2275  g_loss:2.3829
# epoch:1138  d_loss:0.3570  g_loss:2.4374
# epoch:1139  d_loss:0.2488  g_loss:3.2239
# epoch:1140  d_loss:0.2525  g_loss:3.1039
# epoch:1141  d_loss:0.3560  g_loss:2.1575
# epoch:1142  d_loss:0.3233  g_loss:2.5742
# epoch:1143  d_loss:0.3066  g_loss:2.0691
# epoch:1144  d_loss:0.2743  g_loss:2.6970
# epoch:1145  d_loss:0.2627  g_loss:2.8351
# epoch:1146  d_loss:0.3578  g_loss:2.7479
# epoch:1147  d_loss:0.4675  g_loss:2.6086
# epoch:1148  d_loss:0.4610  g_loss:2.2888
# epoch:1149  d_loss:0.5040  g_loss:2.0604
# epoch:1150  d_loss:0.3340  g_loss:2.1461
# epoch:1151  d_loss:0.2424  g_loss:2.2849
# epoch:1152  d_loss:0.3147  g_loss:2.5247
# epoch:1153  d_loss:0.2824  g_loss:2.5791
# epoch:1154  d_loss:0.5281  g_loss:2.4776
# epoch:1155  d_loss:0.5448  g_loss:2.0936
# epoch:1156  d_loss:0.4646  g_loss:1.9847
# epoch:1157  d_loss:0.5140  g_loss:1.5739
# epoch:1158  d_loss:0.3850  g_loss:1.8531
# epoch:1159  d_loss:0.4798  g_loss:1.8328
# epoch:1160  d_loss:0.4842  g_loss:2.1178
# epoch:1161  d_loss:0.4526  g_loss:2.1935
# epoch:1162  d_loss:0.3517  g_loss:2.5283
# epoch:1163  d_loss:0.5270  g_loss:1.9733
# epoch:1164  d_loss:0.6296  g_loss:1.7402
# epoch:1165  d_loss:0.3807  g_loss:2.0413
# epoch:1166  d_loss:0.4688  g_loss:1.9571
# epoch:1167  d_loss:0.5590  g_loss:1.6626
# epoch:1168  d_loss:0.3397  g_loss:1.8608
# epoch:1169  d_loss:0.3622  g_loss:2.4207
# epoch:1170  d_loss:0.3615  g_loss:2.3909
# epoch:1171  d_loss:0.2471  g_loss:2.3504
# epoch:1172  d_loss:0.4115  g_loss:2.1757
# epoch:1173  d_loss:0.4883  g_loss:1.9490
# epoch:1174  d_loss:0.4018  g_loss:2.1127
# epoch:1175  d_loss:0.3872  g_loss:2.4383
# epoch:1176  d_loss:0.2448  g_loss:2.9358
# epoch:1177  d_loss:0.3596  g_loss:2.8370
# epoch:1178  d_loss:0.4125  g_loss:2.5854
# epoch:1179  d_loss:0.4325  g_loss:1.8585
# epoch:1180  d_loss:0.4130  g_loss:1.6863
# epoch:1181  d_loss:0.3247  g_loss:2.1804
# epoch:1182  d_loss:0.2509  g_loss:2.2082
# epoch:1183  d_loss:0.3192  g_loss:2.7629
# epoch:1184  d_loss:0.2049  g_loss:2.9855
# epoch:1185  d_loss:0.4357  g_loss:2.8000
# epoch:1186  d_loss:0.2448  g_loss:2.0580
# epoch:1187  d_loss:0.2410  g_loss:2.3004
# epoch:1188  d_loss:0.3501  g_loss:2.0876
# epoch:1189  d_loss:0.2800  g_loss:2.0717
# epoch:1190  d_loss:0.2405  g_loss:2.2889
# epoch:1191  d_loss:0.3572  g_loss:2.6724
# epoch:1192  d_loss:0.2856  g_loss:2.9757
# epoch:1193  d_loss:0.1654  g_loss:2.7286
# epoch:1194  d_loss:0.4184  g_loss:2.4387
# epoch:1195  d_loss:0.2816  g_loss:2.3124
# epoch:1196  d_loss:0.3422  g_loss:2.0775
# ...
# epoch:1611  d_loss:0.4476  g_loss:2.1802
# epoch:1612  d_loss:0.5457  g_loss:1.7558
# epoch:1613  d_loss:0.4626  g_loss:1.7819
# epoch:1614  d_loss:0.6770  g_loss:1.6833
# epoch:1615  d_loss:0.4464  g_loss:1.5689
# epoch:1616  d_loss:0.4996  g_loss:1.7712
# epoch:1617  d_loss:0.4644  g_loss:1.3591
# epoch:1618  d_loss:0.5172  g_loss:1.5061
# epoch:1619  d_loss:0.4665  g_loss:1.6951
# epoch:1620  d_loss:0.4609  g_loss:1.5624
# epoch:1621  d_loss:0.5878  g_loss:1.6587
# epoch:1622  d_loss:0.5455  g_loss:1.5069
# epoch:1623  d_loss:0.4120  g_loss:1.9905
# epoch:1624  d_loss:0.4665  g_loss:1.9918
# epoch:1625  d_loss:0.6418  g_loss:1.4059
# epoch:1626  d_loss:0.6085  g_loss:1.5532
# epoch:1627  d_loss:0.4122  g_loss:1.6251
# epoch:1628  d_loss:0.6679  g_loss:1.5734
# epoch:1629  d_loss:0.4992  g_loss:1.6384
# epoch:1630  d_loss:0.3292  g_loss:1.9669
# epoch:1631  d_loss:0.5313  g_loss:1.9519
# epoch:1632  d_loss:0.3635  g_loss:1.9180
# epoch:1633  d_loss:0.4293  g_loss:1.7381
# epoch:1634  d_loss:0.4685  g_loss:1.6948
# epoch:1635  d_loss:0.4699  g_loss:1.9713
# epoch:1636  d_loss:0.3724  g_loss:2.0252
# epoch:1637  d_loss:0.3763  g_loss:2.0034
# epoch:1638  d_loss:0.2724  g_loss:2.3788
# epoch:1639  d_loss:0.3720  g_loss:2.5366
# epoch:1640  d_loss:0.4283  g_loss:1.5144
# epoch:1641  d_loss:0.4301  g_loss:1.6364
# epoch:1642  d_loss:0.3281  g_loss:1.9247
# epoch:1643  d_loss:0.2649  g_loss:2.2327
# epoch:1644  d_loss:0.3813  g_loss:2.1878
# epoch:1645  d_loss:0.2934  g_loss:1.9298
# epoch:1646  d_loss:0.2532  g_loss:2.5128
# epoch:1647  d_loss:0.3912  g_loss:2.1454
# epoch:1648  d_loss:0.5050  g_loss:2.2882
# epoch:1649  d_loss:0.3515  g_loss:2.5479
# epoch:1650  d_loss:0.3399  g_loss:2.7109
# epoch:1651  d_loss:0.3003  g_loss:2.3268
# epoch:1652  d_loss:0.4277  g_loss:2.0546
# epoch:1653  d_loss:0.4031  g_loss:2.0707
# epoch:1654  d_loss:0.5275  g_loss:1.5490
# epoch:1655  d_loss:0.5086  g_loss:1.8238
# epoch:1656  d_loss:0.3444  g_loss:2.4770
# epoch:1657  d_loss:0.4307  g_loss:2.4043
# epoch:1658  d_loss:0.5256  g_loss:1.9484
# epoch:1659  d_loss:0.5574  g_loss:1.8035
# epoch:1660  d_loss:0.4516  g_loss:1.3644
# epoch:1661  d_loss:0.3777  g_loss:1.8333
# epoch:1662  d_loss:0.5484  g_loss:1.9722
# epoch:1663  d_loss:0.6615  g_loss:1.4646
# epoch:1664  d_loss:0.5481  g_loss:1.6142
# epoch:1665  d_loss:0.5382  g_loss:1.3984
# epoch:1666  d_loss:0.7447  g_loss:1.3849
# epoch:1667  d_loss:0.6327  g_loss:1.6047
# epoch:1668  d_loss:0.5579  g_loss:1.4446
# epoch:1669  d_loss:0.6203  g_loss:1.8132
# epoch:1670  d_loss:0.4168  g_loss:1.7645
# epoch:1671  d_loss:0.3925  g_loss:1.7202
# epoch:1672  d_loss:0.5778  g_loss:1.5760
# epoch:1673  d_loss:0.4569  g_loss:1.6456
# epoch:1674  d_loss:0.4148  g_loss:1.8846
# epoch:1675  d_loss:0.5118  g_loss:1.6975
# epoch:1676  d_loss:0.3344  g_loss:2.0987
# epoch:1677  d_loss:0.3586  g_loss:1.8838
# epoch:1678  d_loss:0.3958  g_loss:2.0040
# epoch:1679  d_loss:0.5463  g_loss:1.6975
# epoch:1680  d_loss:0.3295  g_loss:1.5875
# epoch:1681  d_loss:0.4303  g_loss:2.1129
# epoch:1682  d_loss:0.3152  g_loss:2.2366
# epoch:1683  d_loss:0.2713  g_loss:2.4358
# epoch:1684  d_loss:0.4696  g_loss:2.3000
# epoch:1685  d_loss:0.4513  g_loss:1.8216
# epoch:1686  d_loss:0.3149  g_loss:2.0386
# epoch:1687  d_loss:0.5571  g_loss:1.8693
# epoch:1688  d_loss:0.4228  g_loss:1.9709
# epoch:1689  d_loss:0.2881  g_loss:2.1990
# epoch:1690  d_loss:0.3702  g_loss:2.2473
# epoch:1691  d_loss:0.4529  g_loss:2.4307
# epoch:1692  d_loss:0.3927  g_loss:1.9835
# epoch:1693  d_loss:0.5884  g_loss:1.6770
# epoch:1694  d_loss:0.4321  g_loss:1.6319
# epoch:1695  d_loss:0.3887  g_loss:2.2448
# epoch:1696  d_loss:0.3449  g_loss:2.0028
# epoch:1697  d_loss:0.4380  g_loss:2.2241
# epoch:1698  d_loss:0.3607  g_loss:2.4010
# epoch:1699  d_loss:0.6176  g_loss:2.2089
# epoch:1700  d_loss:0.4233  g_loss:1.8595
# epoch:1701  d_loss:0.4645  g_loss:1.7620
# epoch:1702  d_loss:0.6366  g_loss:1.2834
# epoch:1703  d_loss:0.6183  g_loss:1.5246
# epoch:1704  d_loss:0.5213  g_loss:2.1833
# epoch:1705  d_loss:0.5586  g_loss:2.0999
# epoch:1706  d_loss:0.4052  g_loss:1.6757
# epoch:1707  d_loss:0.4437  g_loss:1.9024
# epoch:1708  d_loss:0.3843  g_loss:1.4939
# epoch:1709  d_loss:0.5385  g_loss:2.0620
# epoch:1710  d_loss:0.6429  g_loss:1.8801
# epoch:1711  d_loss:0.4958  g_loss:1.5801
# epoch:1712  d_loss:0.6137  g_loss:1.8629
# epoch:1713  d_loss:0.4710  g_loss:1.4825
# epoch:1714  d_loss:0.4641  g_loss:1.6850
# epoch:1715  d_loss:0.5293  g_loss:1.6321
# epoch:1716  d_loss:0.5305  g_loss:1.8116
# epoch:1717  d_loss:0.3792  g_loss:1.8162
# epoch:1718  d_loss:0.5687  g_loss:1.8151
# epoch:1719  d_loss:0.5752  g_loss:1.5704
# epoch:1720  d_loss:0.3245  g_loss:1.7103
# epoch:1721  d_loss:0.4922  g_loss:1.4371
# epoch:1722  d_loss:0.4351  g_loss:1.5344
# epoch:1723  d_loss:0.4541  g_loss:1.6802
# epoch:1724  d_loss:0.4206  g_loss:1.7047
# epoch:1725  d_loss:0.4078  g_loss:1.5417
# epoch:1726  d_loss:0.4151  g_loss:1.6306
# epoch:1727  d_loss:0.4585  g_loss:1.5832
# epoch:1728  d_loss:0.3424  g_loss:1.7331
# epoch:1729  d_loss:0.3993  g_loss:1.8276
# epoch:1730  d_loss:0.3989  g_loss:1.7434
# epoch:1731  d_loss:0.4693  g_loss:1.4644
# epoch:1732  d_loss:0.4932  g_loss:1.7293
# epoch:1733  d_loss:0.5478  g_loss:1.4942
# epoch:1734  d_loss:0.3055  g_loss:2.1070
# epoch:1735  d_loss:0.3382  g_loss:2.1982
# epoch:1736  d_loss:0.3536  g_loss:2.1194
# epoch:1737  d_loss:0.4265  g_loss:2.3424
# epoch:1738  d_loss:0.3395  g_loss:2.2404
# epoch:1739  d_loss:0.3286  g_loss:1.8666
# epoch:1740  d_loss:0.4086  g_loss:1.6876
# epoch:1741  d_loss:0.2819  g_loss:2.0123
# epoch:1742  d_loss:0.4756  g_loss:2.2255
# epoch:1743  d_loss:0.3306  g_loss:2.4276
# epoch:1744  d_loss:0.3444  g_loss:2.7341
# epoch:1745  d_loss:0.2876  g_loss:2.6630
# epoch:1746  d_loss:0.3564  g_loss:2.6190
# epoch:1747  d_loss:0.3857  g_loss:2.0971
# epoch:1748  d_loss:0.3743  g_loss:1.5413
# epoch:1749  d_loss:0.4362  g_loss:1.2193
# epoch:1750  d_loss:0.3431  g_loss:1.8949
# epoch:1751  d_loss:0.4141  g_loss:1.6367
# epoch:1752  d_loss:0.3358  g_loss:2.1863
# epoch:1753  d_loss:0.4022  g_loss:2.1722
# epoch:1754  d_loss:0.5195  g_loss:2.5020
# epoch:1755  d_loss:0.4179  g_loss:2.4005
# epoch:1756  d_loss:0.4954  g_loss:1.9292
# epoch:1757  d_loss:0.5037  g_loss:1.8647
# epoch:1758  d_loss:0.5008  g_loss:1.9505
# epoch:1759  d_loss:0.6086  g_loss:1.7058
# epoch:1760  d_loss:0.5725  g_loss:1.7773
# epoch:1761  d_loss:0.7112  g_loss:1.6944
# epoch:1762  d_loss:0.6000  g_loss:2.0772
# epoch:1763  d_loss:0.7186  g_loss:1.6783
# epoch:1764  d_loss:0.6261  g_loss:1.2103
# epoch:1765  d_loss:0.6116  g_loss:1.2584
# epoch:1766  d_loss:0.4992  g_loss:1.5196
# epoch:1767  d_loss:0.4553  g_loss:1.5690
# epoch:1768  d_loss:0.5263  g_loss:2.2098
# epoch:1769  d_loss:0.5603  g_loss:2.1281
# epoch:1770  d_loss:0.5412  g_loss:1.8256
# epoch:1771  d_loss:0.5084  g_loss:1.7753
# epoch:1772  d_loss:0.6337  g_loss:1.4004
# epoch:1773  d_loss:0.6126  g_loss:1.4607
# epoch:1774  d_loss:0.2766  g_loss:2.1629
# epoch:1775  d_loss:0.4080  g_loss:1.7095
# epoch:1776  d_loss:0.3571  g_loss:1.9955
# epoch:1777  d_loss:0.5529  g_loss:1.7254
# epoch:1778  d_loss:0.5613  g_loss:1.9916
# epoch:1779  d_loss:0.4163  g_loss:2.1555
# epoch:1780  d_loss:0.4932  g_loss:1.7584
# epoch:1781  d_loss:0.3116  g_loss:2.1633
# epoch:1782  d_loss:0.3074  g_loss:1.7908
# epoch:1783  d_loss:0.3431  g_loss:1.8337
# epoch:1784  d_loss:0.5147  g_loss:2.1159
# epoch:1785  d_loss:0.4042  g_loss:2.3333
# epoch:1786  d_loss:0.3579  g_loss:2.5348
# epoch:1787  d_loss:0.3321  g_loss:2.3803
# epoch:1788  d_loss:0.3259  g_loss:2.4017
# epoch:1789  d_loss:0.3648  g_loss:1.6482
# epoch:1790  d_loss:0.4445  g_loss:1.7751
# epoch:1791  d_loss:0.2998  g_loss:2.0900
# epoch:1792  d_loss:0.3625  g_loss:1.7294
# epoch:1793  d_loss:0.3775  g_loss:2.5730
# epoch:1794  d_loss:0.4833  g_loss:2.2328
# epoch:1795  d_loss:0.2680  g_loss:2.4960
# epoch:1796  d_loss:0.3752  g_loss:2.0181
# epoch:1797  d_loss:0.3636  g_loss:1.7604
# epoch:1798  d_loss:0.5716  g_loss:1.7695
# epoch:1799  d_loss:0.6310  g_loss:1.8272
# epoch:1800  d_loss:0.4378  g_loss:1.9720
# epoch:1801  d_loss:0.5712  g_loss:2.3101
# epoch:1802  d_loss:0.4508  g_loss:1.9188
# epoch:1803  d_loss:0.4242  g_loss:2.2213
# epoch:1804  d_loss:0.3949  g_loss:2.0334
# epoch:1805  d_loss:0.6421  g_loss:1.7553
# epoch:1806  d_loss:0.4762  g_loss:1.9321
# epoch:1807  d_loss:0.3723  g_loss:2.4204
# epoch:1808  d_loss:0.3413  g_loss:2.2292
# epoch:1809  d_loss:0.4812  g_loss:1.7250
# epoch:1810  d_loss:0.4647  g_loss:1.9308
# epoch:1811  d_loss:0.3410  g_loss:2.6619
# epoch:1812  d_loss:0.4606  g_loss:2.3930
# epoch:1813  d_loss:0.5322  g_loss:1.7701
# epoch:1814  d_loss:0.3433  g_loss:1.4387
# epoch:1815  d_loss:0.5146  g_loss:1.2873
# epoch:1816  d_loss:0.4912  g_loss:1.7030
# epoch:1817  d_loss:0.4442  g_loss:1.9326
# epoch:1818  d_loss:0.3820  g_loss:2.2992
# epoch:1819  d_loss:0.4568  g_loss:1.7810
# epoch:1820  d_loss:0.3631  g_loss:2.1042
# epoch:1821  d_loss:0.4361  g_loss:1.8890
# epoch:1822  d_loss:0.4000  g_loss:1.5592
# epoch:1823  d_loss:0.5204  g_loss:1.8792
# epoch:1824  d_loss:0.6232  g_loss:1.6126
# epoch:1825  d_loss:0.6139  g_loss:1.2586
# epoch:1826  d_loss:0.4588  g_loss:1.3958
# epoch:1827  d_loss:0.4487  g_loss:1.5468
# epoch:1828  d_loss:0.3961  g_loss:1.6857
# epoch:1829  d_loss:0.5114  g_loss:1.5544
# epoch:1830  d_loss:0.5119  g_loss:1.7337
# epoch:1831  d_loss:0.4854  g_loss:1.7883
# epoch:1832  d_loss:0.5621  g_loss:1.7141
# epoch:1833  d_loss:0.4946  g_loss:1.7002
# epoch:1834  d_loss:0.4777  g_loss:1.6472
# epoch:1835  d_loss:0.5230  g_loss:1.4407
# epoch:1836  d_loss:0.3976  g_loss:1.5356
# epoch:1837  d_loss:0.6266  g_loss:1.4757
# epoch:1838  d_loss:0.4557  g_loss:1.5177
# epoch:1839  d_loss:0.6225  g_loss:1.8531
# epoch:1840  d_loss:0.5325  g_loss:1.7400
# epoch:1841  d_loss:0.4722  g_loss:1.3928
# epoch:1842  d_loss:0.6013  g_loss:1.1964
# epoch:1843  d_loss:0.4574  g_loss:1.1966
# epoch:1844  d_loss:0.4559  g_loss:1.5313
# epoch:1845  d_loss:0.3736  g_loss:2.0482
# epoch:1846  d_loss:0.4854  g_loss:1.7537
# epoch:1847  d_loss:0.4288  g_loss:1.9612
# epoch:1848  d_loss:0.4546  g_loss:2.4924
# epoch:1849  d_loss:0.4801  g_loss:1.9982
# epoch:1850  d_loss:0.4375  g_loss:2.0494
# epoch:1851  d_loss:0.3145  g_loss:1.9088
# epoch:1852  d_loss:0.3636  g_loss:1.8275
# epoch:1853  d_loss:0.5511  g_loss:1.6732
# epoch:1854  d_loss:0.4166  g_loss:1.7799
# epoch:1855  d_loss:0.4815  g_loss:1.6976
# epoch:1856  d_loss:0.2390  g_loss:2.3225
# epoch:1857  d_loss:0.3862  g_loss:1.9289
# epoch:1858  d_loss:0.3344  g_loss:2.0861
# epoch:1859  d_loss:0.4374  g_loss:1.9175
# epoch:1860  d_loss:0.3458  g_loss:1.6669
# epoch:1861  d_loss:0.4420  g_loss:1.7659
# epoch:1862  d_loss:0.3145  g_loss:2.2349
# epoch:1863  d_loss:0.2904  g_loss:1.9916
# epoch:1864  d_loss:0.3676  g_loss:1.6344
# epoch:1865  d_loss:0.4911  g_loss:2.0669
# epoch:1866  d_loss:0.4018  g_loss:2.1142
# epoch:1867  d_loss:0.4291  g_loss:1.5745
# epoch:1868  d_loss:0.5389  g_loss:1.4830
# epoch:1869  d_loss:0.4535  g_loss:1.4300
# epoch:1870  d_loss:0.3897  g_loss:1.7624
# epoch:1871  d_loss:0.4316  g_loss:1.9283
# epoch:1872  d_loss:0.4134  g_loss:1.9676
# epoch:1873  d_loss:0.5805  g_loss:1.8191
# epoch:1874  d_loss:0.3410  g_loss:1.9208
# epoch:1875  d_loss:0.3367  g_loss:1.9792
# epoch:1876  d_loss:0.4811  g_loss:1.8110
# epoch:1877  d_loss:0.4483  g_loss:1.8176
# epoch:1878  d_loss:0.3792  g_loss:2.0068
# epoch:1879  d_loss:0.3364  g_loss:2.1423
# epoch:1880  d_loss:0.6365  g_loss:1.7372
# epoch:1881  d_loss:0.4170  g_loss:1.5679
# epoch:1882  d_loss:0.4313  g_loss:1.4061
# epoch:1883  d_loss:0.5405  g_loss:1.8239
# epoch:1884  d_loss:0.4437  g_loss:1.7117
# epoch:1885  d_loss:0.3155  g_loss:1.8928
# epoch:1886  d_loss:0.4710  g_loss:1.7754
# epoch:1887  d_loss:0.4706  g_loss:1.4544
# epoch:1888  d_loss:0.5165  g_loss:1.6551
# epoch:1889  d_loss:0.5175  g_loss:1.4059
# epoch:1890  d_loss:0.4480  g_loss:1.5754
# epoch:1891  d_loss:0.4245  g_loss:1.6495
# epoch:1892  d_loss:0.4280  g_loss:1.9366
# epoch:1893  d_loss:0.4546  g_loss:1.9531
# epoch:1894  d_loss:0.4769  g_loss:1.8264
# epoch:1895  d_loss:0.4948  g_loss:1.6862
# epoch:1896  d_loss:0.4010  g_loss:1.7998
# epoch:1897  d_loss:0.6177  g_loss:1.4288
# epoch:1898  d_loss:0.5149  g_loss:1.4449
# epoch:1899  d_loss:0.5546  g_loss:1.6128
# epoch:1900  d_loss:0.4069  g_loss:1.5894
# epoch:1901  d_loss:0.3932  g_loss:1.5414
# epoch:1902  d_loss:0.5243  g_loss:1.4644
# epoch:1903  d_loss:0.5532  g_loss:1.5569
# epoch:1904  d_loss:0.5546  g_loss:1.6067
# epoch:1905  d_loss:0.4694  g_loss:1.4552
# epoch:1906  d_loss:0.5343  g_loss:1.5830
# epoch:1907  d_loss:0.5479  g_loss:1.6354
# epoch:1908  d_loss:0.4329  g_loss:1.6634
# epoch:1909  d_loss:0.4271  g_loss:1.8844
# epoch:1910  d_loss:0.6770  g_loss:2.0313
# epoch:1911  d_loss:0.6372  g_loss:1.2575
# epoch:1912  d_loss:0.4618  g_loss:1.4457
# epoch:1913  d_loss:0.5510  g_loss:1.7335
# epoch:1914  d_loss:0.4547  g_loss:1.7898
# epoch:1915  d_loss:0.6658  g_loss:1.4603
# epoch:1916  d_loss:0.4859  g_loss:1.6217
# epoch:1917  d_loss:0.4907  g_loss:1.6253
# epoch:1918  d_loss:0.5194  g_loss:1.7789
# epoch:1919  d_loss:0.5172  g_loss:2.0189
# epoch:1920  d_loss:0.4432  g_loss:1.5523
# epoch:1921  d_loss:0.4096  g_loss:1.8556
# epoch:1922  d_loss:0.5558  g_loss:1.5073
# epoch:1923  d_loss:0.5341  g_loss:1.7674
# epoch:1924  d_loss:0.4993  g_loss:1.9071
# epoch:1925  d_loss:0.5243  g_loss:1.4292
# epoch:1926  d_loss:0.3944  g_loss:1.3803
# epoch:1927  d_loss:0.4848  g_loss:1.7000
# epoch:1928  d_loss:0.4260  g_loss:1.8530
# epoch:1929  d_loss:0.4234  g_loss:2.1052
# epoch:1930  d_loss:0.3917  g_loss:1.8841
# epoch:1931  d_loss:0.4305  g_loss:1.7272
# epoch:1932  d_loss:0.4544  g_loss:1.8565
# epoch:1933  d_loss:0.4667  g_loss:1.3837
# epoch:1934  d_loss:0.4167  g_loss:1.7127
# epoch:1935  d_loss:0.4841  g_loss:1.4853
# epoch:1936  d_loss:0.4596  g_loss:1.6270
# epoch:1937  d_loss:0.4782  g_loss:1.4308
# epoch:1938  d_loss:0.4936  g_loss:1.4989
# epoch:1939  d_loss:0.4276  g_loss:1.8111
# epoch:1940  d_loss:0.4881  g_loss:1.9184
# epoch:1941  d_loss:0.4034  g_loss:1.9225
# epoch:1942  d_loss:0.4261  g_loss:1.8975
# epoch:1943  d_loss:0.5167  g_loss:1.6349
# epoch:1944  d_loss:0.4072  g_loss:1.6655
# epoch:1945  d_loss:0.5094  g_loss:1.5219
# epoch:1946  d_loss:0.4481  g_loss:1.3203
# epoch:1947  d_loss:0.4544  g_loss:1.6044
# epoch:1948  d_loss:0.3864  g_loss:1.9239
# epoch:1949  d_loss:0.4361  g_loss:1.9746
# epoch:1950  d_loss:0.5242  g_loss:2.2762
# epoch:1951  d_loss:0.5500  g_loss:1.7130
# epoch:1952  d_loss:0.5871  g_loss:1.7536
# epoch:1953  d_loss:0.8074  g_loss:1.3434
# epoch:1954  d_loss:0.6923  g_loss:1.3297
# epoch:1955  d_loss:0.5484  g_loss:1.2211
# epoch:1956  d_loss:0.4239  g_loss:1.8082
# epoch:1957  d_loss:0.3701  g_loss:2.1801
# epoch:1958  d_loss:0.4403  g_loss:1.9828
# epoch:1959  d_loss:0.7511  g_loss:1.2964
# epoch:1960  d_loss:0.5435  g_loss:1.4433
# epoch:1961  d_loss:0.6082  g_loss:1.3333
# epoch:1962  d_loss:0.4503  g_loss:1.3452
# epoch:1963  d_loss:0.5108  g_loss:1.4475
# epoch:1964  d_loss:0.4856  g_loss:1.7630
# epoch:1965  d_loss:0.4283  g_loss:1.8672
# epoch:1966  d_loss:0.4249  g_loss:1.7904
# epoch:1967  d_loss:0.5649  g_loss:1.5982
# epoch:1968  d_loss:0.5572  g_loss:1.4047
# epoch:1969  d_loss:0.5382  g_loss:1.2781
# epoch:1970  d_loss:0.4192  g_loss:1.2825
# epoch:1971  d_loss:0.4058  g_loss:1.7023
# epoch:1972  d_loss:0.4346  g_loss:1.6250
# epoch:1973  d_loss:0.6407  g_loss:1.6562
# epoch:1974  d_loss:0.4344  g_loss:1.5299
# epoch:1975  d_loss:0.5581  g_loss:1.3825
# epoch:1976  d_loss:0.6560  g_loss:1.3110
# epoch:1977  d_loss:0.6493  g_loss:1.3625
# epoch:1978  d_loss:0.5406  g_loss:1.7135
# epoch:1979  d_loss:0.5658  g_loss:1.7407
# epoch:1980  d_loss:0.4678  g_loss:1.6785
# epoch:1981  d_loss:0.5632  g_loss:1.5060
# epoch:1982  d_loss:0.5773  g_loss:1.3486
# epoch:1983  d_loss:0.4218  g_loss:1.3374
# epoch:1984  d_loss:0.4909  g_loss:1.7511
# epoch:1985  d_loss:0.4322  g_loss:2.1113
# epoch:1986  d_loss:0.3813  g_loss:1.6524
# epoch:1987  d_loss:0.4640  g_loss:1.5961
# epoch:1988  d_loss:0.5450  g_loss:1.4029
# epoch:1989  d_loss:0.4984  g_loss:1.4863
# epoch:1990  d_loss:0.4762  g_loss:1.3684
# epoch:1991  d_loss:0.4963  g_loss:1.4494
# epoch:1992  d_loss:0.3528  g_loss:1.7469
# epoch:1993  d_loss:0.3290  g_loss:1.7521
# epoch:1994  d_loss:0.3410  g_loss:1.7851
# epoch:1995  d_loss:0.5116  g_loss:1.7360
# epoch:1996  d_loss:0.2782  g_loss:2.0485
# epoch:1997  d_loss:0.3637  g_loss:2.0561
# epoch:1998  d_loss:0.3677  g_loss:1.3436
# epoch:1999  d_loss:0.4304  g_loss:1.6375
# epoch:2000  d_loss:0.4202  g_loss:1.8926
