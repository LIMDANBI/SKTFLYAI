# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #  선형 회귀 -경사하강법
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-07-28%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%209.58.11.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-07-28%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%209.58.11.png)

# %%
X = np.array([0., 1. ,2.])
y = np.array([3., 3.5, 5.5])

# %%
W = 0 # 기울기
b = 0 # 절편

# %%
lr = 0.01
epochs = 10000
n = float(len(X))

# %%
for epoch in range(epochs):
    y_pred = W*X + b
    dW = (2/n)*sum(X*(y_pred-y))
    db = (2/n)*sum(y_pred-y)
    W -= lr*dW
    b -= lr*db

# %%
print(W, b)
# Out:
# 1.2500000000000244 2.7499999999999645

# %%
y_pred = W*X+b
y_pred
# Out:
# array([2.75, 4.  , 5.25])

# %%
plt.scatter(X, y)
plt.plot([min(X), max(X)], [min(y_pred), max(y_pred)], color='red') 
plt.show()

# %% [markdown]
# # Sklearn - Linear Regression

# %%
from sklearn import linear_model

# %%
X = [[174], [152], [138], [128], [186]] 
y = [71, 55, 46, 38, 88]

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.predict([[165]])
# Out:
# array([67.30998637])

# %%
plt.scatter(X, y, color='black')
y_pred = reg.predict(X)
plt.plot(X, y_pred, color='blue', linewidth=3)
plt.show()

# %% [markdown]
# # diabetes data

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
diabetes = datasets.load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.2, random_state=0)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
plt.plot(y_test, y_pred, '.')
x = np.linspace(0, 330, 100)
y=x
plt.plot(x, y)
plt.show()
